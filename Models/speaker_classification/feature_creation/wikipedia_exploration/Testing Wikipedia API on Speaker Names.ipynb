# %% [markdown]
# ## Set up Wikipedia API

# %%
# !pip install wikipedia
# Out:
# Requirement already satisfied: wikipedia in c:\users\tiffl\anaconda3\lib\site-packages (1.4.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\tiffl\anaconda3\lib\site-packages (from wikipedia) (4.6.0)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in c:\users\tiffl\anaconda3\lib\site-packages (from wikipedia) (2.18.4)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\tiffl\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in c:\users\tiffl\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in c:\users\tiffl\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tiffl\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2018.4.16)
# WARNING: You are using pip version 19.1.1, however version 21.3.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import wikipedia
# the following imports resolve the certificate error
import os
import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)
os.environ['CURL_CA_BUNDLE'] = ""
os.environ['PYTHONWARNINGS']="ignore:Unverified HTTPS request"

# %% [markdown]
# ## Load in Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("GNI88.csv")
data.head(2)
# Out:
#       artdate  Article ID                             Headline  Quote ID  \
# 0  2018-01-10     3759306  North Korea makes deals and threats   7023849
# 1  2018-01-10     3759306  North Korea makes deals and threats   7023842
#
#   Article Status Article Position           Messages  \
# 0           News          Neutral  OLD Proliferation
# 1           News          Neutral  OLD Proliferation
#
#                         Submessages Quote Position Legacy Quote Tag  ...  \
# 0  OLD State Level Nuclear Programs        Neutral              NaN  ...
# 1  OLD State Level Nuclear Programs       Negative              NaN  ...
#
#   Source Religion Legacy Source Tag    Constituent Group       Media Name  \
# 0         Unknown           Unknown  None (Legacy Other)  Washington Post
# 1         Unknown           Unknown  None (Legacy Other)  Washington Post
#
#   Media Medium Journalist Name Constituent Author Article Issues Custom Group  \
# 0          NaN   Fifield, Anna                NaN            NaN          NaN
# 1          NaN   Fifield, Anna                NaN            NaN          NaN
#
#   Media Group
# 0         NaN
# 1         NaN
#
# [2 rows x 28 columns]

# %%
# Filter out the non-names from the dataset

#non_name_regex = ".*(?:staff$|staff ).*|Letters to the Editor|from.*|(?i).*editorial.*|(?i).*editors.*|No by-line,|(?i).*readers.*|(?i)blog$"
nonname_flags = ['Unnamed', 'Unknown', 'Official', 'Spokesperson', 'Statement', 'Foreign', 'Lawmaker',
                 'Military','Navy','Advocacy','Journal', 'Analyst',
                 'Government','Agency', 'Agencies', 'Ministry','Department']
df = data[~data['Source Name'].str.contains('|'.join(nonname_flags), na=False)]

# %%
speakers = df['Source Name'].unique()
print("Number of unique speakers:", len(speakers))
print("Number of non-names:", len(data['Source Name'].unique()) - len(speakers))
# Out:
# Number of unique speakers: 14239
# Number of non-names: 1162

# %%
data['Source Type'].unique()
# Out:
# array(['Foreign Gov/Mil Official', 'Federal Official', 'US Military',
#        'Citizen', 'Media/Journalist', 'US Rep. & Staff',
#        'State/Local Official', 'US Senate & Staff', 'Analyst/Commentator',
#        'Nuke Organization - Academic', 'Non-Profit/NGO',
#        'Nuke Organization', 'Other', 'Former Admin. Officials',
#        'Think Tanks', 'Academic', 'Partisans/Fmr. Politicians',
#        'International Orgs', 'Judicial Official', 'Regulator',
#        'Corporate Official', 'Blogger', 'Public Polling', 'Attorney', nan,
#        'Nuclear Scientist', 'Religious/Clerical', 'US Police',
#        'Terrorist/Extremist', 'Ambassador', 'Defense', 'Defense Forces',
#        'Information minister', 'Deputy', 'Nuke Organization - Other',
#        'Nuclear Official', 'Chairman'], dtype=object)

# %% [markdown]
# ## Testing Wikipedia API on Speaker Names

# %% [markdown]
# Using wikipedia.summary() directly can raise a disambiguation error because there are multiple possible search results. To work around this while keeping runtime costs down, it is assumed that the first item that wikipedia.search() returns is what we'd want.
#
# However, this can also lead to an increase of false results if there just isn't a corresponding wikipedia page. sameName() is a helper function to determine whether two different strings are referring to the same person.

# %%
import re
from difflib import SequenceMatcher

"""Compares two strings and returns true if they're likely the same name.
Approx parameter accounts for nicknames (e.g., James Mattis as Jim)"""
def sameName(name1, name2, approx=True):
    name1 = re.sub(r'[^a-zA-Z]', '', name1).lower() #only alphabetic characters, lowercase
    name2 = re.sub(r'[^a-zA-Z]', '', name2).lower()
    if approx:
        if SequenceMatcher(a=name1,b=name2).ratio() > 0.7: #somewhat arbitrary; ratio of James Mattis / Jim Mattis = 0.81
            return True
    if name1 == name2 or name1 in name2 or name2 in name1:
        return True
    return False

#test
print(sameName('Kim Jong-un', 'kim jong'))
print(sameName('James Mattis', 'Jim Mattis'))
# Out:
# True
# True

# %%
"""Takes in list of speakers, outputs 
- a dictionary with the speaker name and the corresponding first two sentences from the wikipedia summary
- a list of names that errored."""
def getSummary(speakers):
    error_names = []
    dict = {}
    for name in speakers: 
        try: 
            pageTitle = wikipedia.search(name)[0] #assuming the first term will most closely match
            if not sameName(name, pageTitle):
                error_names.append(name)
                continue
            wiki_summary = wikipedia.summary(pageTitle, sentences = 2, auto_suggest=False) 
            #auto_suggest=False makes sure the function will use the literal input; code will bug otherwise
        except: 
            error_names.append(name)
        else: 
            dict[name] = wiki_summary
    return dict, error_names

# %%
# %%time 

summary, error_names = getSummary(speakers[:5001]) #~3hrs to run whole dataset
# Out:
# Wall time: 59min 58s

# %%
summary_df = pd.DataFrame.from_dict(summary, orient='index').reset_index()

# %%
summary_df.to_csv("wiki_summary_5000.csv",index=False)

# %%
summary_df.head()
# Out:
#               index                                                  0
# 0     \nMoon Jae-in  Moon Jae-in (Korean: 문재인; Hanja: 文在寅; Korean p...
# 1       Ri Son Gwon  Ri Son-gwon (Korean: 리선권) is a North Korean po...
# 2  Cho Myoung- Gyon  Cho Myoung-gyon (Korean: 조명균; Hanja: 趙明均; born...
# 3        Paul Selva  Paul Joseph Selva (born September 27, 1958) is...
# 4  Donald Trump OLD  Donald John Trump (born June 14, 1946) is an A...

# %%
print("Number of Errors:", len(error_names))
print("Percent of Errors:", len(error_names)/5000)
error_names #still has some non-names from misspellings and noncomprehensive filter list earlier; account for case-sensitive
# more filter words: diplomat, think tank, media, advisers, Administration, U.N., Media, Air Force, 
# Army, Diplomat, Experts, Report, source, deal, poll, command, citizen
# Out:
# Number of Errors: 2290
# ['Rob Soofer',
#  'Lisa Foxen',
#  'Atji Pai',
#  'Hiroyuku Suenaga',
#  'Baek Tae-Hyun',
#  'Lu Kang',
#  'Many analysts',
#  'Fumiaki Kubo',
#  'Greg Weaver',
#  'Sapan Shah',
#  'Uri Friedman (OLD)',
#  'David Welna',
#  'Alexander Golts',
#  'Malcolm Chalmers',
#  'Report DOD',
#  'Euan Graham',
#  'Zhang Liangui',
#  'Evans J.R. Revere',
#  'Stephen Noerper',
#  'Citizen South Korea',
#  'Former U.S official',
#  'Pavel Podvig (Russian Nuclear Forces Project)',
#  'Go Myong-Hyun',
#  'Masoud Jazayeri',
#  'Charles Schumer',
#  'Michele Kelemen',
#  'Joshua Pollack',
#  'Tong Zhao',
#  'Aidan Foster-Carter',
#  'Du Hyeogn Cha',
#  'Koh Yu-hwan',
#  'Rahul Bedi',
#  'Goverment China',
#  'Christopher Hill',
#  'Kim Hack-yong',
#  'Yang Shilong',
#  'Robert A. Wood',
#  'Marta Vicentini',
#  'Harry Harris',
#  'Patrick McEachern',
#  'Alexander Shein',
#  'William Potter',
#  'Joseph Pae',
#  'Leif-Eric Easley',
#  'Alexandra Bell (Constituent)',
#  'Christine Wormuth (OLD)',
#  'Daryl Kimball',
#  'Jenny Town',
#  'Kingston Reif',
#  'Yuri Borisov',
#  'Yoon Young-chan',
#  'Chun Hae-sung',
#  'Harry Kazianis',
#  'Ken Gause',
#  'Clifford Gaddy',
#  'Roh Jae-cheon',
#  'Suzanne Dimaggio (OLD)',
#  'Adm. Mike Mullen',
#  'Greg Mckenna',
#  'Heiko Mass',
#  'Adam Mount',
#  'Paul Nolte',
#  'David S. Maxwell',
#  'Bruce Bechtol',
#  'Jung Gwang II',
#  'Mintaro Oba',
#  'Son-hui Choe',
#  'Will Ripley',
#  'Lee Seong-hyon',
#  'Moon Seong-mook',
#  'Mireya Solis',
#  'Fred Wambier',
#  'Olivia Enos',
#  'Im Yang-bin',
#  'Troy Stangarone',
#  'Kim Keonwook',
#  'Moon Hong-sik',
#  'Joel Wit',
#  'David Schmerler',
#  'Duyeon Kim (OLD CACNP)',
#  'Kim Eui-keum',
#  'Anna Borshchevskaya',
#  'Dimitry Polyansky',
#  'Karel Van Oosterom',
#  'Gary Samore OLD',
#  'William Perry',
#  'Aron Bernstein',
#  'Howard Eissenstaat',
#  'Departament US Treasury',
#  'Ri Yong Ho',
#  'Melissa Hanham',
#  'Keith Englander',
#  'Peter Harrell',
#  'Commercial Vehicles Daimler',
#  'Ankit Panda (OLD)',
#  'Grace Liu',
#  'Jin Qiangyi',
#  'Xuan Dongri',
#  'Michael Madden',
#  'Seo Yu-Suk',
#  nan,
#  'Unnanmed Critics',
#  'John Park',
#  'Chisuke Masuo',
#  'Sharon Squassoni',
#  'Reinhard BÃ¼tikofer',
#  'Norbert RÃ¶ttgen',
#  'Tetsuo Kotani',
#  'Wang Zixin',
#  'Jeff Schlegelmilch',
#  'Jeffery Feltman',
#  'Setsuko Surlow',
#  'Victor Baranets',
#  'Vladimir Dvorkin',
#  'Pavel Zolotaryov',
#  'Alexander Konovalov',
#  'Michael Elleman',
#  'Scott LaFoy',
#  'Sung Baikyou',
#  'Rob Manning',
#  'Norm Montano',
#  'Rick Lehner',
#  'Steve Nicholls',
#  'Karen Bell',
#  'Adam Wash',
#  'Joseph Cirincione (OLD)',
#  'Poll Washington Post/ABC',
#  'Marshall Mathers III',
#  'Dylan Williams',
#  'Kim In Ryong',
#  '\nJohn Sullivan',
#  'Sung-nam Lim',
#  'Ria Tolstoi',
#  'Narushige Michishita',
#  'Eui-yong Chung',
#  'Joseph DeThomas',
#  'Woo Young-soo',
#  'Shin Hee-Seok',
#  'Chang Kyung-soo',
#  'Steven Gibbons',
#  'Gen. Jang Kyung-soo',
#  'Garren Mulloy',
#  'Alexander Gabuev',
#  'Report intelligence',
#  'Ralph Vartabedian',
#  'Philip Coyle',
#  'Cheong Seong-chang',
#  'Jon Rainwater',
#  'Yi Wang',
#  'Leon Segal',
#  'Francois Delaterre',
#  'Cha Du-hyeogn',
#  'Scott Bray',
#  'Chris Steinitz',
#  'Pacific U.S. Command',
#  'Bruce Klinger',
#  'Meredith Horowski',
#  'Bonnie Docherty',
#  'Wang Dong',
#  'Shi Yinhong',
#  'James D. Syring',
#  'Jonathan D. Pollack',
#  'Wee Seung Ho',
#  'Yong Choi Ju',
#  'Kim Dong-yub',
#  'Du Xiaojun',
#  'Seok-hyun Hong',
#  'Lee Duk-haeng',
#  'Yoichi Funabashi',
#  'David Straub',
#  'Marcus Noland',
#  'Jong-seok Lee',
#  'Dean Chengdu',
#  'Thom Mason',
#  'Andrea Stricker',
#  'Joe Biden OLD',
#  'Evan Medeiros',
#  'Wu Qian',
#  'Brad Glosserman',
#  'Gregory Spriggs',
#  'Cho Tae-yul',
#  'Command U.S. Strategic',
#  'Bill Perry',
#  'David Mastaio',
#  'Min-Koo Han',
#  'Kelsey Davenport',
#  'Ernest Moniz OLD',
#  'Michael McKenna',
#  'Corri Zoli',
#  'Robert Kelley',
#  'Richard Bush',
#  'Benjamin Rhodes',
#  'John Kirby OLD',
#  'Sara Vakhshouri',
#  'Hardliners Iranian',
#  'IranPoll.com',
#  'Yang Yujun',
#  'Evan Montgomery',
#  'Ashton B Carter OLD',
#  'James Miller',
#  'Jim Walsh',
#  'Howard LaFranchi',
#  'Kathy Serra',
#  'Andrew Weiss',
#  'James Collins',
#  'Josh Earnest OLD',
#  'Dennis Wilder',
#  'Report RAND',
#  'Shawn Marshall',
#  'Dina Smeltz',
#  'Marc Turi',
#  'Jim Jeffrey',
#  'James R. Clapper OLD',
#  'Irina Karmanina',
#  'Irina Tsareva',
#  'Citizen Russian',
#  'Andrey Kolesnikov',
#  'Jon Alterman',
#  'Mohsen Ghamsari',
#  'Tariq Zahir',
#  'Peter Wilson',
#  'Elizabeth Trudeau',
#  'Kim Kyong Ik',
#  'Paul  Kawika Martin ',
#  'Michaela Dodge',
#  'Brett Schaefer',
#  'Sue Cange',
#  'Robert Einhorn',
#  'B.B. Sinha',
#  'Jacob Nagel',
#  'Erdal Kuyumcu',
#  'Cho June-hyuck',
#  'Jennifer Psaki OLD',
#  'Amy Dudley',
#  'Nasser Karimi',
#  'Saeed Nikbkhat',
#  'Wang Junsheng',
#  'Bob Fertik',
#  'CREDO Action',
#  'Llya Sheyman',
#  'David Montague',
#  'Cristina Chaplain',
#  'Marie E. Harf OLD',
#  "Organization Iran's Atomic Energy",
#  'Randall Larsen',
#  'Miguel Garcia ',
#  'Brian Todd',
#  'Meir Elram',
#  'Shlomo Maslawy',
#  'Ben Rhodes OLD',
#  'Kim Ki Nam',
#  'Mehdi Asali',
#  'Denis McDonough OLD',
#  'EBRD',
#  'James Phillips',
#  'Public Poll',
#  'Many officials',
#  'Sung Kim',
#  'Simond Degalbert',
#  'Ilan Goldenberg ',
#  'Ian Kearns',
#  'Kwon Sejin',
#  'Lee Choon Geun',
#  'U.N.\r\nMeir Javedanfar',
#  'Austin Long',
#  'Boris Makarenko',
#  'Thomas Countryman (OLD)',
#  'RomÃ¡n Oyarzun Marchesi',
#  'Michelle Reichert',
#  'John Richardson',
#  'United Nations U.S. Mission',
#  'Aengus Kelly',
#  'Go Myung',
#  'University Huston',
#  'Hong Lei',
#  'Li Zhang',
#  'Farhan Haq',
#  'Ernie Brown',
#  'Martin Nesirky',
#  'Nuclear deal/Neg With Iran Critics',
#  'Nadezhda Mamonova',
#  'Alexei Mukhin',
#  'Natalya Knorre',
#  'Jaiki Lee',
#  'U.S. Geological',
#  'Shanghai News',
#  'Sergei Karakayev',
#  'John Fleming',
#  'Eric Schultz OLD',
#  'Patrick Dorton',
#  'Ned Price (Constituent)',
#  'Of the nuclear deal Supporters',
#  'Levi McDaniel',
#  'Stuart Hinnefeld',
#  'Kevin Breslin',
#  'Joyce Connery',
#  'J. Matthew McInnis',
#  'Report IAEA',
#  'Rainer Seele',
#  'Ben Armbruster (OLD CAP)',
#  'Matt Duss',
#  'Hamid Reza Taraghi',
#  'Shmuel Bar',
#  'Bruce Held',
#  'Keri Fulton',
#  'John King',
#  'Susan E. Rice OLD',
#  'Robert Casey',
#  'Kent Peters',
#  'Christopher Harmer',
#  'Michael Singh',
#  'Caitlin M. Hayden OLD',
#  'Amy Kellogg',
#  'Saeed Leilaz',
#  'Theodore Karasik',
#  'Jay Carney OLD',
#  'Farhad Bashiri',
#  'Turki Al-Faisal',
#  'Mohsen Rajabi',
#  'Citizen India',
#  'Yoginder Kaul',
#  'Yacov Livne',
#  'Patrick Ventrell',
#  'Hahm Chaibong',
#  'Joseph I. Lieberman OLD',
#  'John Collick',
#  'Paul Hommert',
#  'Jay Coghlan',
#  'Suzanne Maloney',
#  'Roman Vassilenko',
#  'Ali Gharib',
#  'William Fallon',
#  'Joshua Holdenried',
#  'Colin Kahl (Constituent)',
#  'Farshad Ghorbanpour',
#  'Ali Reza Matachi',
#  'Ahmad Bakhshayesh',
#  'Gholam Reza Jalali',
#  'James Lewis',
#  'Eli Clifton',
#  'Elise Labott',
#  'Mark Hibbs',
#  'Hossein Bastani',
#  'Reza Kahlili',
#  'Alan Baker',
#  'Gadi Wolfsfeld',
#  'Ted Carter',
#  'Chris Lawrence',
#  'Hamilton William ',
#  'Rouzbeh Pirouz',
#  'Ramin Rabii',
#  'Hossein Sheikholeslami',
#  'Report SOI',
#  'Wendy Sherman OLD',
#  'Peter King',
#  'Maja Kocijancic',
#  'Goverment India',
#  'The Washington Free Bacon',
#  'Adam Kredo',
#  'Tim Peter Johnson',
#  'Richard Durbin',
#  'Thomas Buonomo',
#  'Naghmeh Abedini',
#  'Gary Hufbauer',
#  'Massoud Daneshmand',
#  'Ali Khatibi',
#  'David Wech',
#  'Alexander Lukashevich',
#  'Ren Xiao',
#  'Andy Lipow',
#  'George Little OLD',
#  'Fereydoun Abbasi-Davani',
#  'George Lewis',
#  'Emil Maine',
#  'Laura Rozen',
#  'Alexei Makarkin',
#  'Citizen North Korea',
#  'Halef Al-Muftah',
#  'Jacob Dayan',
#  'Glyn Davies',
#  'Neile Miller',
#  'Greg Mello',
#  'Joshua C. Himes',
#  'David B. Crist',
#  'Bruno Tertrais',
#  'Tommy Vietor OLD',
#  'Cai Jian',
#  'Liu Weimin',
#  'Jonathan Rue',
#  'Mustafa Alani',
#  'John Kilduff',
#  'Tancred Lidderdale',
#  'Michael Krepon',
#  'Thorbjoern Bak Jensen',
#  'Gordon Flake (Mansfield)',
#  'Afshon Ostovar',
#  'Mohammad Abdzadeh',
#  'Chong Chol-Ho',
#  'Baek Seung-joo',
#  'Lee Chang-jin',
#  'John Kline',
#  'Shlomo Brom',
#  'Ali Alfoneh',
#  'Mohammad Kossari',
#  'Blaise Misztal',
#  'News Iran',
#  'Karunaratne Amunugama',
#  'John Sullivan',
#  'Dean Boyd',
#  'Susan Yip',
#  'Ali Hajighasemi',
#  'Ardeshir Amir Arjomand',
#  'Kazem Kardevani',
#  'Tom Collina',
#  'Kenneth Katzman',
#  'Christian Emery',
#  'Alan Fraser',
#  'Scott Lucas',
#  'Eytan Gilboa',
#  'Jia Qingguo',
#  'Stephanie Kleine-Ahlbrandt',
#  'Gregory Kulacki',
#  'Mark Stokes',
#  'Kang Jung-min',
#  'Saeed Qasemi',
#  'Abbas Khani',
#  'George A. Buskirk Jr.',
#  'Richard Whitman',
#  'Rouzbeh Parsi',
#  'Patrick Kennedy',
#  'Hamid Emadi',
#  'Lee Seung-yeol',
#  'Ruediger Luedeking',
#  'Ali Vaez OLD',
#  'Marie Bos',
#  'Tim Ripley',
#  'Sean Kay',
#  'Shamsedin Husseini',
#  'Ephraim Kam',
#  'Derek Scissors',
#  'Maseh Zarif',
#  'R. Scott Kemp',
#  'Caroline Rabbitt',
#  'Avaz Heidarpour',
#  'Report IHS',
#  'Ali Reza Khamesian',
#  "Report Iran's state TV",
#  'Eskandar Sadeghi- Boroujerdi',
#  'Meron Reuben',
#  'Doron Gavish',
#  'Greyson Vanwinkle',
#  'Kasha Baxter',
#  'Nancy Vanwinkle',
#  'James Hardy',
#  'Experts UN Panel ',
#  'Diplomat Western',
#  'Lou Dolinar',
#  'Grigory Berdennikov',
#  'Adam Meyers',
#  'Mike Reavey',
#  'Roel Schouwenberg',
#  'Madelyn Creedon',
#  'Ted Sherry',
#  'Frank Munger',
#  'Christopher White',
#  'Ben Ray LujÃ¡n',
#  'Report Turkish Police',
#  'Ekrer Aydiner',
#  'Muammer Akkas',
#  "Turkey's media",
#  "Weekly Jane's Defense ",
#  'DNI',
#  'Stephen Young',
#  'Steven Wyatt',
#  'David Feith',
#  'Benjamin Weinthal',
#  'Benny Avni',
#  'Farhad Alavi',
#  'Scott M. Flicker',
#  'Robert Malley (Constituent)',
#  'Chung Jae-ho',
#  'Richard Gowan',
#  'Peter Willetts',
#  'Alexander Glaser',
#  'Pete Spotts',
#  'James Russell',
#  'Michael Maloof',
#  'Wi Sung-lac',
#  'Bulent Aliriza',
#  'For Change Americans United',
#  'Keith Maley',
#  'Aides Democratic',
#  'Jeff Rathke',
#  'Judy Gutnam',
#  'Bobby Grazioso',
#  'Efraim Inbar',
#  'Abdulattif al-Zayani',
#  'Howard Kohr',
#  'Alon Roth-Snir',
#  'Employee Bank Saderat',
#  'Rhonda Shore',
#  'Mohammad Mohaddessin',
#  'News Mehr',
#  'Vahid Ahmadi',
#  'Farideh Farhi',
#  'Kim Sung-hwan',
#  'Robert Vercher',
#  'Angie Blair',
#  'Jay Folds',
#  'Assessment Intelligence',
#  'Bernard Valero',
#  'Wang Qun',
#  'Jeremy Herb',
#  'Jeffrey Farnquist',
#  'Bernard Weinstein',
#  'Michaela Bendikova',
#  'Charles Vick',
#  'Herman Nackaerts',
#  'John O. Brennan OLD',
#  'Annika Thunborg',
#  'Jeffrey Park',
#  'Khaled Kidwai',
#  'So Se Pyong',
#  'Kwon Haeryong',
#  'BusinessWeek Bloomberg',
#  'Tsutomu Sugimori',
#  'Moon Jaedo',
#  'Andy Culbreath',
#  'Mohammad Mahdi Akhondzadehhe',
#  'Paul Norman',
#  'Maziar Ebrahimi',
#  'Arash Kheradkish',
#  'Behzad Abdoli',
#  'Sami Alfaraj',
#  'Elbridge Colby',
#  'Kamran Napelian',
#  'Saadullah Zareie',
#  'Alexander Gostev',
#  'Victor Shum',
#  'Yasushi Kimura',
#  'Aziz Shah Mohammadi',
#  'John Logsden',
#  'Ismail Salami',
#  'Gill Tudor',
#  'Najid Namjou',
#  'Denny Roy',
#  'Shahrokh Noooshabadi',
#  'Jofi Joseph',
#  'Itai Brun',
#  'Marty Coyne',
#  'Resolution Arab Nations',
#  "Iran's Central Bank",
#  'Bradley Gordon',
#  'Afshin Rezayee Haddad',
#  'Michael Kassen',
#  'Markus Schiller',
#  'Pieter Wezeman',
#  'Greystone Ltd.',
#  'Jim Trump',
#  'Mackenzie Eaglen',
#  'Kate Dickens',
#  'Rose Gottemoeller (OLD)',
#  'Treaty INF',
#  'Rick Wayman',
#  'Heikelina Verrijn Stuart',
#  'Nico Schrijver',
#  'Phon Van den Biesen',
#  'ICJ',
#  'International Securi Institue for Science',
#  'George Little',
#  'Arieh Herzog',
#  'Yu Chang-seon',
#  'Jang Sung-min',
#  'Yang Moo-jin',
#  'Hong Sung-gul',
#  'Hayes Brown',
#  'Roger Cavazos',
#  'Lee Ji-sue',
#  'Han Yong-sup',
#  'Gabriel Gomez',
#  'Robert McNally',
#  'Charles Dent',
#  'Thomas Muetzelburg',
#  'Samir Saran',
#  'Vladimir Chuprov',
#  'Behjat Ghasemi',
#  'Jin Yinan',
#  'Hojjatoleslam Ebrahimi',
#  'Elliott Abrams OLD',
#  'Maryam Firouzi',
#  'Reza Sharifi',
#  'Mohsen Sedghi',
#  'Saba Mirzai',
#  'Morteza Ghaderi',
#  'Guo Haitao',
#  'Fariborz Ghadar',
#  'David Lorello',
#  'Thomas Donnelly',
#  'Cho Byung-jae',
#  'Nader Modanlo',
#  'Joel Faulkner Rogers',
#  'Susan Voss',
#  'Christophe Blanchard',
#  'SDP',
#  'Will Hartley',
#  'Emad Hosseini',
#  'Alpana Killawala',
#  'Mehdi Nabizadeh',
#  'Ali Ahani',
#  'Hasan Sharafi',
#  'Shota Utiashvili',
#  'Reuven Pedatzur',
#  'Mike Herzog',
#  'B.K. Gupta',
#  'Mohammad Shirdel',
#  'Michael A. Braun',
#  'G.C. Chaturvedi',
#  'Cheryl Amerine',
#  'Vladimir Padalko',
#  'Eduardo Gamarra',
#  'Hamid Farahvashi',
#  'Abolqasem Hakimipour',
#  'Kevin Haley',
#  'Balazs Csuday',
#  'Hossein Ibrahimi',
#  'Jurgen Grobe',
#  'Jang Ji-Hyang',
#  'Hooman Peimani',
#  'Chang Byung-ock',
#  'Darrel Kohlhorst',
#  'Han Chung- hee',
#  'Igor Barinov',
#  'Gennady Gatilov',
#  'Shannon Kile',
#  'Sal Russo',
#  'Tin Win',
#  'David Fulghum',
#  'Todd Copeland',
#  'A.B. Onifade',
#  'Elaine Tyler May',
#  'Philipp Ackermann',
#  'William Tobey',
#  'Zohre Tayebzadeh',
#  'Nejatollah Ebrahimian',
#  'Shmuley Boeteach ',
#  'Ran Baratz',
#  'Mahdi Fattahi',
#  'Maysam Bizar',
#  'Jeremy Bennie',
#  'Andrea Zopp',
#  'Idriss Jazairy',
#  'Seth B. Rosen',
#  'The Hill',
#  'Marzban Mortaz',
#  'Yonah Bookstein',
#  'Tim Evans',
#  'Eric H. Holder OLD',
#  'Andrew Ames',
#  'Mehrzad Boroujerdi',
#  'Suleyman Aslan',
#  'Bijan Khajehpour',
#  'Bob Peurifoy',
#  'Robert Blaha',
#  'Brian Stetler',
#  'Ji Jae Ryong',
#  'UKEF',
#  'CACNP Report',
#  'U.S. Arab Allies',
#  'Glen Bramhall',
#  'Police Moldova',
#  'Vladimir Mosneaga',
#  'Jens Nagel',
#  'Services Committee Senate Armed ',
#  'Ramazan Sharif',
#  'Song II Ho',
#  'Boaz Ben Zur',
#  'William Burns (Obama and Biden Admin.)',
#  'Ali Sabzevari',
#  'Mardonio Jimenez',
#  'Russell Rhoads',
#  'Eben Harrell',
#  'Sifiso Dabengwa',
#  'Amy Derrick-Frost',
#  'Thitima Chaisaeng',
#  'Spokesman NATO',
#  'Bhushan Bahree',
#  'Ahmad Qalebani',
#  'Tetsu Emori',
#  'Eugen Weinberg',
#  'Gordon  Adams',
#  'Hesham Tuffaha',
#  'Robert Knight',
#  'Bin Al-Hussein Abdullah II',
#  'Hassan Vosughi',
#  'Mahsa Sedri',
#  'Marty Edwards',
#  'James Carroll',
#  'Dave Lapan',
#  'Group Ofer Brothers',
#  'Bokhari Kamran',
#  'Robin Bravender',
#  'Keith Koffler',
#  'Brian Bolduc',
#  'Theodore Bromund',
#  'U.S. Police',
#  'Richard Johnson (Constituent)',
#  'Unamed source Source Unamed',
#  'Media Report',
#  'Dummy Source Type 1',
#  'Richard Stratford',
#  'Dummy Source Type 21',
#  'Evans Revere',
#  'Rachel Bronson',
#  'Evgeny Lukyanov',
#  'David Krieger',
#  'Cheong Seong-whun',
#  'Behnam Taleblu',
#  'Kim Eui-kyeom',
#  'Michael Fuchs (CAP)',
#  'Daniel Coats',
#  'Shan Desai',
#  'George Perkovich',
#  'Srinivasan Sitaraman',
#  'Bucky Hellwig',
#  'Laura Grego',
#  'Trump Administration ',
#  'Woo Jung-yeop',
#  'Moon Jang-nyeol ',
#  'Kwon Jong Gun',
#  'David Brown',
#  'Rostec Corp.',
#  'Garret Marquis',
#  'Jim Phillips',
#  'Aaron Stein',
#  'William Burns (Constituent)',
#  'Jason Poblete',
#  'Matt Korda',
#  'United Nations Experts ',
#  'Report United Nations',
#  'Valentin Kostyukov',
#  'Vyacheslav Solovyov',
#  'Dmitry Zhuravlev',
#  'Pavel Salin',
#  'Jean Lee',
#  'Joint Chief Staff Seoul',
#  'French officials',
#  'Gaddafi’s sons ',
#  'Mona Neuhass',
#  'R. Scott Kemp MIT',
#  'Great Britain, Germany and France ',
#  'Wealth Minerals Ltd ',
#  'Thomas  DiNanno',
#  'Kyle Rempfer',
#  ' David Maxwell',
#  'Clarence Wendel',
#  "Iran's Atomic Energy Commission ",
#  'Kazem Gharibabadi',
#  'Iran Diplomat ',
#  'NPT',
#  'Rachel Minyoung Lee',
#  'Shin Beomchul',
#  'Russian Defense Industry ',
#  'Duyeon Kim (OLD ICG)',
#  'Vladimir Yermakov',
#  'Joseph Bermudez',
#  'Christopher Bolan',
#  'Cindy Warmbier',
#  'Fred Warmbier',
#  'Democratic Senator',
#  'Col. Ren Guoqiang',
#  'James Fanell',
#  'France, Great Britain & United States ',
#  'Ross Mercer',
#  'Brenda Bachman',
#  'Nuclear Experts ',
#  'Zhang Taon',
#  'Alan  Kuperman',
#  'Miles Pomper',
#  'Dan Brouillete OLD',
#  'Corey Hinderstein',
#  'Ariane Tabatabai (RAND)',
#  'Ellie Geranmayeh',
#  'Ian Bond',
#  'Kim Eun-han',
#  'Sahil Shah',
#  'Fabian Hinz',
#  'Shaylyn Hynes',
#  'Lynn Rusten',
#  'Panelist United Nations ',
#  'Yousuf Bin Alawi bin Abdullah',
#  ' Abbas Ali Kadkhodaei',
#  'Trump Critics ',
#  'Jon Hill',
#  'Allison Bawden',
#  'Kang Min-seok',
#  'Katy Oh',
#  'Leif Eric Easly',
#  'Jung H. Pak (Brookings)',
#  'U.N Resolution',
#  'U.S European Allies ',
#  'Erica Fein',
#  'Derek Johnson',
#  'Kim Hong-gul',
#  'Hops Hossbach',
#  'Dennis DuVall',
#  'Larry Pfeiffer',
#  'Zuzanna Sitek',
#  'Willie Williams',
#  'Alexi Drew',
#  'Nobuko Bamba',
#  'Wang  Shaopu',
#  'Joshua Shrager',
#  'The Sentry ',
#  'David Brunnstrom',
#  'Ari Natter',
#  'U.N. Security Council diplomat  ',
#  'Doug Berenson',
#  'Sok Eysan',
#  'Markus Garlauskas',
#  'South Korean state-run think tank ',
#  'Lucian Kim',
#  'Talal Al Faisal',
#  'Pavel Felgengauer',
#  "Joe Biden's advisers ",
#  'Helima Croft',
#  'WarIsBoring ',
#  'ICANA Media ',
#  'Marcus Weisgerber',
#  'Ankit Panda',
#  'Cheon Seong Whun',
#  'Duyeon Kim',
#  'Cailin Birch',
#  'Sydney Seiler',
#  'Mark Bell',
#  'Joe Biden Administration ',
#  'Bonnie Jenkins (Constituent)',
#  'Alireza Miryousefi',
#  'Nasser Hadian',
#  'Saeed Khatibzadeh',
#  'Esfandyar  Batmanghelidj',
#  'Hadi  Kahalzadeh',
#  ' Independent U.N. sanctions monitors  ',
#  'North Korea Diplomat ',
#  'Manish Parashar',
#  'Robert Malley (Biden Admin.)',
#  'Dina Esfandiary',
#  'Iranian State Media ',
#  'Yoel Gozansky',
#  'Kan Broadcaster ',
#  'Annie Linskey',
#  'Hyonhee Shin',
#  'Matthew Lee',
#  'Yuri Rogulyov',
#  'Review Nuclear Posture',
#  'Russ Bynum',
#  'Dr. Ran Zwigenberg ',
#  'Shuichi Adachi ',
#  'Ben Wolfgang',
#  'Melissa Dalton (Biden Admin.)',
#  'Mr. Del Toro ',
#  'Senate Armed Services Committee',
#  'Tracy Wilkinson',
#  'Fred Guterl',
#  'Toby Dalton',
#  'Lee Jong-joo',
#  'Rebeccah Heinrichs',
#  'All STRATCOM ',
#  'U.S. Air Force',
#  'Fred Kaplan',
#  'Ryan  Hanna',
#  'Angelo Panebianco',
#  'Ben Makuch',
#  ' Rasha  Al Aqeedi',
#  'U.N Nuclear Watchdog',
#  'Frank McKenzie',
#  'U.S. Army',
#  'William Hartung',
#  'Tom Karako',
#  'Scott  Lehr',
#  'Stacy Cummings',
#  'Benjamin Friedman',
#  'Col. Dave Butler',
#  "Gen. Milley's ",
#  'Hugh White',
#  'Bill Merz',
#  'Danny Hernandez',
#  'Harold Johnson ',
#  'Frederick  Stefany ',
#  'Michael Smith',
#  'Sina Toossi',
#  'Arthur Hummel',
#  'Rick Fisher ',
#  'Paul Mcleary',
#  'Zhao Tong',
#  'Dean Cheng',
#  'Tai Ming Cheung',
#  'Michael Gerrard',
#  'Brian Katulis',
#  'Alex Biese',
#  'Alastair Gale',
#  'Monitor Christian Science',
#  'Caroline Cochran',
#  'Jeff Navin',
#  ' Brett Rampal',
#  'Heather Caygle',
#  'Edoardo Saravalle',
#  'Mary Wareham',
#  'Joel Vowell',
#  'Gerhard Mangott',
#  'Nikkei Business Daily',
#  'Megan Eckstein',
#  'Brad Lendon',
#  'Max Tani',
#  " North Korea's mission to the United Nations ",
#  'Bong Youngshik',
#  'Bong-Hyun Cho',
#  'Daniel Gonzales',
#  'Emile El Hokayem',
#  'Victor Gilinsky',
#  'Becky Anderson Wilkins',
#  'Matthew Brolley',
#  'Jeremy Wynes',
#  'Andrew OÂ´Neil',
#  'Joseph Siracusa',
#  'Priscilla Moriuchi',
#  'Thomas Karako',
#  'Owen Sirrs',
#  'Robert Schmucker',
#  'Brig. Gen. Stephen Maranian',
#  'James L. Schoff',
#  'Brig. Gen Randy McIntire',
#  'Brigadier Gl Gregory Bowen',
#  'Katina Adams',
#  'David French',
#  'Joseph Jaushieh Wu',
#  'Korea North ',
#  'Wu Haitao',
#  'Nobushige Takamizawa',
#  'Valerie Lincy',
#  'Michael Short',
#  'Evan Rees',
#  'Kim Chul-woo',
#  'Takashi Kawakami',
#  'Hee Young',
#  'Gi-Wook Shin',
#  'Christopher Logan',
#  'James Mckeon',
#  'Ellen Ahn ',
#  'Da Zhigang',
#  'Ri Pyong Hwi',
#  'Pascal Wallisch',
#  'Wendy Cutler',
#  'Kim Heung-kyu',
#  'Laura Rosenberger',
#  'Junichi Ishikawa',
#  'Pak Son OK',
#  'Alexander Zhebin',
#  'Vladimir Kolotov',
#  'David Shin',
#  'Zachary Zwald',
#  'Jae Lee',
#  'Yoo Dong-ryul',
#  'Shahab Mousavi',
#  'Isaac Chotiner',
#  'Kay Dong',
#  'Kang Hyung Seok',
#  'Myong Sool Chang',
#  'June Kim',
#  'Laicie Heeley (Inkstick)',
#  'Chuk Worshim',
#  'Jong-hee Lee',
#  'Poll CNN/ORC',
#  'Byeong-uk Kim',
#  'Yoon Je Cho',
#  'Nam Gwan pyo',
#  'Cho Young-key',
#  'Kuyoun Chung',
#  'Jarrett Blanc',
#  'Rachel Ziemba ',
#  'Barry Ladendorf',
#  'William Darne ',
#  'Mel Melvin Ernest Hupfeld',
#  'Alexander Voronstov',
#  'Suh Kyun-ryul',
#  'Michael Lambrau',
#  'Mark Valdez',
#  'Karen Lindsay',
#  'Zachary Keck',
#  'Gamal Gawad',
#  'Michael Duitsman',
#  'Noboru Yamaguchi',
#  'Tytti Erasto',
#  'Behnam Ben Taleblu',
#  'Kim Young-Joon',
#  'Hochul Lee',
#  'Iman Brivanlou',
#  'Carter Copeland',
#  'John O. Brennan',
#  'Rebecca Hersman',
#  'Kevin Jon Heller',
#  ...]

# %% [markdown]
# ## Feature Testing
#
# Ideas
# - flag for music / popculture summaries (may indicate wrong associated person)
# - account for  key words like "former" and "was..." (e.g., if a politican has formerly served in the military, can confuse classification)

# %%
#'|'.join(nonname_flags)
# case insensitive regex: /aBc/i would match AbC
media_flags = 'journalist|newspaper|website|magazine|news|agency'
US_military_flags = 'general|air force|commander|army|navy|marine' #add indicator for US as well
foreign_gov_flags = 'foreign|south korea|iran|north korea|china|prime minister'
academic_flags = 'professor|academic|academia|college|university'

# %% [markdown]
# ## Suggested Key Words
#
# Government
# - politican
# - administration
# - diplomat
# - government official
# - president
# - senator
# - democrat
# - republican
# - representative
# - policy advisor
# - prime minister
# - judge
#
# Academic
# - professor
# - academic
#
# Media
# - journalist
# - newspaper
# - website
# - magazine
# - news agency
#
# Military
# - general
# - air force
# - commander
# - army
# - navy
# - marine
