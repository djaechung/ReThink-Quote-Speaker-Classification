# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import numpy as np

# %%
treaty_message_table = pd.read_csv('treaty_message_table')

# %%
treaty_message_table
# Out:
#      Unnamed: 0                                         treaty  \
# 0             0            the nuclear nonproliferation treaty
# 1             1                    the nonproliferation treaty
# 2             2                      the north atlantic treaty
# 3             3                           the new start treaty
# 4             4    the intermediaterange nuclear forces treaty
# ..          ...                                            ...
# 127         127                          the arms trade treaty
# 128         128                        the panama canal treaty
# 129         129                        the iran nuclear treaty
# 130         130                                the oslo treaty
# 131         131  the organization's founding washington treaty
#
#      most common message
# 0               OLD Iran
# 1               OLD Iran
# 2    OLD Missile Defense
# 3     OLD Arms Reduction
# 4     OLD Arms Reduction
# ..                   ...
# 127  OLD Missile Defense
# 128             OLD Iran
# 129    OLD Proliferation
# 130    OLD Proliferation
# 131             OLD Iran
#
# [132 rows x 3 columns]

# %%
merged_df = pd.read_csv('merged_df')

# %%
merged_df.head()
# Out:
#    Unnamed: 0     artdate  Article ID                             Headline  \
# 0           0  2018-01-10     3759306  North Korea makes deals and threats
# 1           1  2018-01-10     3759306  North Korea makes deals and threats
# 2           2  2018-01-10     3759306  North Korea makes deals and threats
# 3           3  2018-01-10     3759306  North Korea makes deals and threats
# 4           4  2018-01-10     3759306  North Korea makes deals and threats
#
#    Quote ID Article Status Article Position           Messages  \
# 0   7023849           News          Neutral  OLD Proliferation
# 1   7023842           News          Neutral  OLD Proliferation
# 2   7023839           News          Neutral  OLD Proliferation
# 3   7023833           News          Neutral  OLD Proliferation
# 4   7023846           News          Neutral  OLD Proliferation
#
#                         Submessages Quote Position  ... Article Issues  \
# 0  OLD State Level Nuclear Programs        Neutral  ...            NaN
# 1  OLD State Level Nuclear Programs       Negative  ...            NaN
# 2  OLD State Level Nuclear Programs       Negative  ...            NaN
# 3  OLD State Level Nuclear Programs       Negative  ...            NaN
# 4  OLD State Level Nuclear Programs       Positive  ...            NaN
#
#   Custom Group Media Group                                            Content  \
# 0          NaN         NaN  North Korea makes deals and threats\r\n\r\nMed...
# 1          NaN         NaN  North Korea makes deals and threats\r\n\r\nMed...
# 2          NaN         NaN  North Korea makes deals and threats\r\n\r\nMed...
# 3          NaN         NaN  North Korea makes deals and threats\r\n\r\nMed...
# 4          NaN         NaN  North Korea makes deals and threats\r\n\r\nMed...
#
#           Author          Published Date  \
# 0  Fifield, Anna  2018-01-10 00:00:00+00
# 1  Fifield, Anna  2018-01-10 00:00:00+00
# 2  Fifield, Anna  2018-01-10 00:00:00+00
# 3  Fifield, Anna  2018-01-10 00:00:00+00
# 4  Fifield, Anna  2018-01-10 00:00:00+00
#
#                                    First_10%_Content  \
# 0  SEOUL - North Korea's representatives assured ...
# 1  SEOUL - North Korea's representatives assured ...
# 2  SEOUL - North Korea's representatives assured ...
# 3  SEOUL - North Korea's representatives assured ...
# 4  SEOUL - North Korea's representatives assured ...
#
#                              First_10%_Content_Split Treaty_Instances  \
# 0  ['SEOUL', '-', 'North', "Korea's", 'representa...               []
# 1  ['SEOUL', '-', 'North', "Korea's", 'representa...               []
# 2  ['SEOUL', '-', 'North', "Korea's", 'representa...               []
# 3  ['SEOUL', '-', 'North', "Korea's", 'representa...               []
# 4  ['SEOUL', '-', 'North', "Korea's", 'representa...               []
#
#   Treaties2
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#
# [5 rows x 36 columns]

# %%
# extract articles with mentions of treaties
treaty_articles = merged_df.dropna(subset=['Treaties2'])

# %%
treaty_articles = treaty_articles.loc[treaty_articles['Treaties2'].isin(treaty_message_table['treaty'])]

# %%
predicted_message = []
for i in np.arange(len(treaty_articles)):
    # find treaty in treaty_message_table, append most common message
    treaty = treaty_articles.reset_index()['Treaties2'][i]
    treaty_message = treaty_message_table.loc[treaty_message_table['treaty'] == treaty]['most common message'].item()
    predicted_message.append(treaty_message)

# %%
true_predicted_message_table = treaty_articles[['Messages']].reset_index(drop=True)
true_predicted_message_table['predicted_message'] = predicted_message
true_predicted_message_table = true_predicted_message_table.rename(columns= {'Messages': 'true_message'})

# %%
true_predicted_message_table
# Out:
#               true_message    predicted_message
# 0       OLD Arms Reduction   OLD Arms Reduction
# 1       OLD Arms Reduction   OLD Arms Reduction
# 2       OLD Arms Reduction   OLD Arms Reduction
# 3        OLD Proliferation             OLD Iran
# 4        OLD Proliferation             OLD Iran
# ...                    ...                  ...
# 10584   OLD Arms Reduction   OLD Arms Reduction
# 10585    OLD Proliferation   OLD Arms Reduction
# 10586  OLD Missile Defense  OLD Missile Defense
# 10587   OLD Arms Reduction  OLD Missile Defense
# 10588  OLD Missile Defense  OLD Missile Defense
#
# [10589 rows x 2 columns]

# %%
correct = sum(true_predicted_message_table['true_message'] == true_predicted_message_table['predicted_message'])
total = len(true_predicted_message_table)
accuracy = correct/total
accuracy
# Out:
# 0.5761639437151761

# %% [markdown]
# # relationship between Treaty and Topic (submessages)

# %%
len(merged_df['Treaties2'].value_counts())
# Out:
# 134

# %%
submessages_treates = merged_df[['Treaties2', 'Submessages']]

# %%
merged_df['Submessages'].value_counts()
# Out:
# OLD Negotiations                        87980
# OLD State Level Nuclear Programs        73337
# OLD Sanctions                           29007
# OLD Iranian Domestic Politics           23389
# OLD Deployment and Testing              17811
# OLD Russia Reset                        10396
# OLD Domestic Programs                    7774
# OLD European/Russian Missile Defense     7164
# OLD  Politics                            5967
# OLD US Arsenal                           4994
# OLD Covert Ops                           4368
# OLD Iran Rapid Response                  4208
# OLD Iran                                 4190
# OLD Loose Nuclear Materials              3064
# OLD Arms Reduction                       2754
# OLD START Treaty                         2681
# OLD Modernization                        2160
# OLD Nukes Budget Campaign                1620
# OLD Terrorist Threat                     1565
# OLD Foreign Policy Narrative             1533
# OLD Other                                 779
# OLD NPT                                   761
# OLD NSA Budget                            750
# OLD Spending                              546
# OLD CTBT                                  538
# OLD Tactical Nukes Treaty                 325
# OLD Proliferation                         264
# OLD INF Treaty                            217
# OLD AQ Khan Network                       176
# OLD Non-Proliferation                     161
# OLD Fissile Material Cut Off Treaty       113
# OLD Sequestration                          87
# OLD Missile Defense                        62
# US/NATO Missile Defense                    36
# Conflict with North Korea                  21
# North Korea Deployments                    18
# Spending and Modernization                 16
# Loose Fissile Materials                    12
# NATO Arsenal                               10
# US Nuclear Arsenal                          7
# Iran Negotiations                           5
# Iran Sanctions                              5
# Iran Nuclear Activity                       4
# START                                       4
# North Korea Negotiations                    4
# JCPOA                                       3
# Health Issues                               2
# China Negotiations                          2
# OLD Russia Negotiations 2019                1
# India Nuclear Activity                      1
# North Korea Nuclear Activity                1
# NPT                                         1
# Conflict with Iran                          1
# Worldwide Nukes Policy                      1
# Name: Submessages, dtype: int64

# %%
def submessage_treaty_table(treaty, topic_column):
    table =  merged_df.loc[merged_df['Treaties2'] == treaty].groupby(by = topic_column).count()
    return table.reset_index().iloc[:,0:2].rename(columns = {'Unnamed: 0' : 'count'})

# %%
submessage_treaty_table('the nuclear nonproliferation treaty', 'Submessages')
# Out:
#                              Submessages  count
# 0                                    NPT      1
# 1                          OLD  Politics     11
# 2                    OLD AQ Khan Network      2
# 3                     OLD Arms Reduction    117
# 4                               OLD CTBT      5
# 5                         OLD Covert Ops     16
# 6             OLD Deployment and Testing     48
# 7                  OLD Domestic Programs      6
# 8   OLD European/Russian Missile Defense     22
# 9    OLD Fissile Material Cut Off Treaty      3
# 10          OLD Foreign Policy Narrative      4
# 11                              OLD Iran     25
# 12               OLD Iran Rapid Response     25
# 13         OLD Iranian Domestic Politics    630
# 14           OLD Loose Nuclear Materials     16
# 15                     OLD Modernization      3
# 16                               OLD NPT    272
# 17                      OLD Negotiations   1520
# 18                 OLD Non-Proliferation      4
# 19             OLD Nukes Budget Campaign      4
# 20                             OLD Other      3
# 21                     OLD Proliferation      6
# 22                      OLD Russia Reset     13
# 23                      OLD START Treaty      6
# 24                         OLD Sanctions    221
# 25      OLD State Level Nuclear Programs    991
# 26             OLD Tactical Nukes Treaty     14
# 27                  OLD Terrorist Threat     15
# 28                        OLD US Arsenal     39
# 29                    US Nuclear Arsenal      1

# %%
treaties_unique = pd.DataFrame(merged_df['Treaties2'].value_counts())
treaties_unique#.loc[treaties_unique['Treaties2'] > 50]
# Out:
#                                                Treaties2
# the nuclear nonproliferation treaty                 4043
# the nonproliferation treaty                          879
# the north atlantic treaty                            741
# the new start treaty                                 545
# the intermediaterange nuclear forces treaty          543
# ...                                                  ...
# the panama canal treaty                                1
# the iran nuclear treaty                                1
# the oslo treaty                                        1
# the organization's founding washington treaty          1
# the alliance’s founding washington treaty              1
#
# [134 rows x 1 columns]

# %% [markdown]
# # find proportion of articles with the given treaty in the different Submessages

# %%
def submessage_treaty_props(treaty, topic_column):
    table =  merged_df.loc[merged_df['Treaties2'] == treaty].groupby(by = topic_column).count()
    table = table.reset_index().iloc[:,0:2].rename(columns = {'Unnamed: 0' : 'count'})
    total = sum(table['count'])
    props = []
    for i in np.arange(len(table)):
        props.append(table['count'][i] / total)
    table['props'] = props
    table['treaty'] = treaty
    return table[['treaty', topic_column, 'props']]

# %%
# treaties most --> least common
treaties_list = treaties_unique.index

# %%
treaty_submessage_table = submessage_treaty_props(treaties_list[0], 'Submessages')
treaty_submessage_table= pd.pivot_table(treaty_submessage_table, values = 'props', index = ['treaty'], columns = ['Submessages'])

for i in treaties_list[1:]:
    table = submessage_treaty_props(i, 'Submessages')
    table = pd.pivot_table(table, values = 'props', index = ['treaty'], columns = ['Submessages'])
    treaty_submessage_table = pd.concat([treaty_submessage_table, table])

# %%
pd.set_option('display.max_rows', len(treaty_submessage_table))
treaty_submessage_table
# Out:
# Submessages                                              NPT  OLD  Politics  \
# treaty
# the nuclear nonproliferation treaty                 0.000247       0.002721
# the nonproliferation treaty                              NaN       0.003417
# the north atlantic treaty                                NaN       0.096467
# the new start treaty                                     NaN       0.031193
# the intermediaterange nuclear forces treaty              NaN       0.037244
# the treaty                                               NaN       0.017045
# the comprehensive test ban treaty                        NaN       0.002959
# the antiballistic missile treaty                         NaN       0.043137
# the inf treaty                                           NaN       0.004878
# the comprehensive nucleartestban treaty                  NaN            NaN
# the 1968 nuclear nonproliferation treaty                 NaN       0.035928
# the 1970 nuclear nonproliferation treaty                 NaN            NaN
# the strategic arms reduction treaty                      NaN       0.055556
# the nuclear non proliferation treaty                     NaN            NaN
# the comprehensive testban treaty                         NaN            NaN
# the 1972 antiballistic missile treaty                    NaN            NaN
# the international nuclear nonproliferation treaty        NaN            NaN
# the start treaty                                         NaN            NaN
# the intermediate nuclear forces treaty                   NaN            NaN
# the 2015 nuclear nonproliferation treaty                 NaN            NaN
# the nato treaty                                          NaN            NaN
# the 2010 new start treaty                                NaN            NaN
# the limited test ban treaty                              NaN            NaN
# the abm treaty                                           NaN            NaN
# the non proliferation treaty                             NaN            NaN
# the north american treaty                                NaN            NaN
# the npt (nonproliferation treaty                         NaN            NaN
# the global nonproliferation treaty                       NaN            NaN
# the nuclearnonproliferation treaty                       NaN            NaN
# the 1970 nonproliferation treaty                         NaN            NaN
# the [nuclear nonproliferation treaty                     NaN            NaN
# the nuclear test ban treaty                              NaN            NaN
# the washington treaty                                    NaN       0.100000
# the comprehensive nuclear testban treaty                 NaN            NaN
# the strategic offensive reductions treaty                NaN            NaN
# the u.n.'s nuclear nonproliferation treaty               NaN            NaN
# the sea treaty                                           NaN            NaN
# the fissile material cutoff treaty                       NaN            NaN
# the nowdefunct antiballistic missile treaty              NaN            NaN
# the 1968 nonproliferation treaty                         NaN            NaN
# the parliament's move.=========================...       NaN            NaN
# the comprehensive nucleartest ban treaty                 NaN            NaN
# the international nonproliferation treaty                NaN            NaN
# the global nuclear nonproliferation treaty               NaN            NaN
# the 1987 inf treaty                                      NaN       0.047619
# the 189nation nuclear nonproliferation treaty            NaN            NaN
# the 1967 outer space treaty                              NaN            NaN
# the u.s.russia new start treaty                          NaN            NaN
# the outer space treaty                                   NaN            NaN
# the threshold test ban treaty                            NaN       0.166667
# the npt (nuclear nonproliferation treaty                 NaN            NaN
# the strategic arms limitation treaty                     NaN       0.117647
# the intermediaterange forces treaty                      NaN       0.058824
# the firstever treaty                                     NaN            NaN
# the decadesold nuclear nonproliferation treaty           NaN            NaN
# the 2011 new start treaty                                NaN            NaN
# the 1992 open skies treaty                               NaN            NaN
# the 47yearold nuclear nonproliferation treaty            NaN            NaN
# the open skies treaty                                    NaN            NaN
# the landmark nuclear nonproliferation treaty             NaN            NaN
# the rushedthrough new start treaty                       NaN       0.214286
# the nuclear proliferation treaty                         NaN            NaN
# the valuable nuclear nonproliferation treaty             NaN            NaN
# the congressional test ban treaty                        NaN            NaN
# the u.n. treaty                                          NaN            NaN
# the 1990 treaty                                          NaN            NaN
# the i.n.f. treaty                                        NaN            NaN
# the international antiballistic missile treaty           NaN            NaN
# the next north atlantic treaty                           NaN            NaN
# the u.s.soviet antiballistic missile treaty              NaN            NaN
# the (nuclear nonproliferation treaty                     NaN            NaN
# the first postinf treaty                                 NaN            NaN
# the 1996 comprehensive nucleartestban treaty             NaN            NaN
# the intermediate missile treaty                          NaN            NaN
# the vaunted new start treaty                             NaN            NaN
# the versailles treaty                                    NaN            NaN
# the u.n. arms trade treaty                               NaN            NaN
# the southeast asia treaty                                NaN            NaN
# the ineffective new start treaty                         NaN            NaN
# the seventhcentury treaty                                NaN            NaN
# the 28member north atlantic treaty                       NaN       1.000000
# the state department's treaty                            NaN       0.142857
# the union's 2009 lisbon treaty                           NaN            NaN
# the un's comprehensive testban treaty                    NaN            NaN
# the 1972antiballistic missile (abm) treaty               NaN            NaN
# the socalled new start treaty                            NaN            NaN
# the fiveyear nuclear nonproliferation treaty             NaN            NaN
# the 2002 moscow treaty                                   NaN            NaN
# the intermediatenuclear forces treaty                    NaN            NaN
# the 1997 ukrainerussia bilateral treaty                  NaN            NaN
# the second nuclear nonproliferation treaty               NaN            NaN
# the moribund antiballistic missile treaty                NaN            NaN
# the viennabased comprehensive nucleartestban tr...       NaN            NaN
# the onepage moscow treaty                                NaN            NaN
# the useuratom treaty                                     NaN            NaN
# the clintondesigned, abm treaty                          NaN            NaN
# the 1970 treaty                                          NaN            NaN
# the un treaty                                            NaN            NaN
# the partial test ban treaty                              NaN            NaN
# the collective security treaty                           NaN            NaN
# the antiballistic missile defense treaty                 NaN            NaN
# the 1972 abm treaty                                      NaN            NaN
# the obamaputin new start treaty                          NaN       0.250000
# the longstanding nuclear nonproliferation treaty         NaN            NaN
# the npt [nuclear nonproliferation treaty                 NaN            NaN
# the north atlantaic treaty                               NaN            NaN
# the 10page treaty                                        NaN            NaN
# the central treaty                                       NaN       1.000000
# the 2017 united nations treaty                           NaN            NaN
# the 1987 treaty                                          NaN            NaN
# the july, 2017, u.n. treaty                              NaN            NaN
# the abandoned start ii treaty                            NaN            NaN
# the 1970 non proliferation treaty                        NaN            NaN
# the ornate treaty                                        NaN            NaN
# the francogerman aachen treaty                           NaN            NaN
# the 1949 north atlantic treaty                           NaN            NaN
# the punitive versailles treaty                           NaN            NaN
# the new strategic reductions treaty                      NaN            NaN
# the existingintermediaterange nuclear forces tr...       NaN            NaN
# the western pacific. treaty                              NaN            NaN
# the separate nuclear nonproliferation treaty             NaN            NaN
# the command “supports #openskies treaty                  NaN            NaN
# the u.s.japan treaty                                     NaN            NaN
# the 96hour treaty                                        NaN            NaN
# the 1963 francogerman elysée treaty                      NaN            NaN
# the mine ban treaty                                      NaN       1.000000
# the summit, north atlantic treaty                        NaN            NaN
# the arms trade treaty                                    NaN            NaN
# the panama canal treaty                                  NaN            NaN
# the iran nuclear treaty                                  NaN            NaN
# the oslo treaty                                          NaN            NaN
# the organization's founding washington treaty            NaN            NaN
#
# Submessages                                         OLD AQ Khan Network  \
# treaty
# the nuclear nonproliferation treaty                            0.000495
# the nonproliferation treaty                                         NaN
# the north atlantic treaty                                           NaN
# the new start treaty                                                NaN
# the intermediaterange nuclear forces treaty                         NaN
# the treaty                                                          NaN
# the comprehensive test ban treaty                                   NaN
# the antiballistic missile treaty                                    NaN
# the inf treaty                                                      NaN
# the comprehensive nucleartestban treaty                             NaN
# the 1968 nuclear nonproliferation treaty                            NaN
# the 1970 nuclear nonproliferation treaty                            NaN
# the strategic arms reduction treaty                                 NaN
# the nuclear non proliferation treaty                                NaN
# the comprehensive testban treaty                                    NaN
# the 1972 antiballistic missile treaty                               NaN
# the international nuclear nonproliferation treaty                   NaN
# the start treaty                                                    NaN
# the intermediate nuclear forces treaty                              NaN
# the 2015 nuclear nonproliferation treaty                            NaN
# the nato treaty                                                     NaN
# the 2010 new start treaty                                           NaN
# the limited test ban treaty                                         NaN
# the abm treaty                                                      NaN
# the non proliferation treaty                                        NaN
# the north american treaty                                           NaN
# the npt (nonproliferation treaty                                    NaN
# the global nonproliferation treaty                                  NaN
# the nuclearnonproliferation treaty                                  NaN
# the 1970 nonproliferation treaty                                    NaN
# the [nuclear nonproliferation treaty                                NaN
# the nuclear test ban treaty                                         NaN
# the washington treaty                                               NaN
# the comprehensive nuclear testban treaty                            NaN
# the strategic offensive reductions treaty                           NaN
# the u.n.'s nuclear nonproliferation treaty                          NaN
# the sea treaty                                                      NaN
# the fissile material cutoff treaty                                  NaN
# the nowdefunct antiballistic missile treaty                         NaN
# the 1968 nonproliferation treaty                                    NaN
# the parliament's move.=========================...                  NaN
# the comprehensive nucleartest ban treaty                            NaN
# the international nonproliferation treaty                           NaN
# the global nuclear nonproliferation treaty                          NaN
# the 1987 inf treaty                                                 NaN
# the 189nation nuclear nonproliferation treaty                       NaN
# the 1967 outer space treaty                                         NaN
# the u.s.russia new start treaty                                     NaN
# the outer space treaty                                              NaN
# the threshold test ban treaty                                       NaN
# the npt (nuclear nonproliferation treaty                            NaN
# the strategic arms limitation treaty                                NaN
# the intermediaterange forces treaty                                 NaN
# the firstever treaty                                                NaN
# the decadesold nuclear nonproliferation treaty                      NaN
# the 2011 new start treaty                                           NaN
# the 1992 open skies treaty                                          NaN
# the 47yearold nuclear nonproliferation treaty                       NaN
# the open skies treaty                                               NaN
# the landmark nuclear nonproliferation treaty                        NaN
# the rushedthrough new start treaty                                  NaN
# the nuclear proliferation treaty                                    NaN
# the valuable nuclear nonproliferation treaty                        NaN
# the congressional test ban treaty                                   NaN
# the u.n. treaty                                                     NaN
# the 1990 treaty                                                     NaN
# the i.n.f. treaty                                                   NaN
# the international antiballistic missile treaty                      NaN
# the next north atlantic treaty                                      NaN
# the u.s.soviet antiballistic missile treaty                         NaN
# the (nuclear nonproliferation treaty                                NaN
# the first postinf treaty                                            NaN
# the 1996 comprehensive nucleartestban treaty                        NaN
# the intermediate missile treaty                                     NaN
# the vaunted new start treaty                                        NaN
# the versailles treaty                                               NaN
# the u.n. arms trade treaty                                          NaN
# the southeast asia treaty                                           NaN
# the ineffective new start treaty                                    NaN
# the seventhcentury treaty                                           NaN
# the 28member north atlantic treaty                                  NaN
# the state department's treaty                                       NaN
# the union's 2009 lisbon treaty                                      NaN
# the un's comprehensive testban treaty                               NaN
# the 1972antiballistic missile (abm) treaty                          NaN
# the socalled new start treaty                                       NaN
# the fiveyear nuclear nonproliferation treaty                        NaN
# the 2002 moscow treaty                                              NaN
# the intermediatenuclear forces treaty                               NaN
# the 1997 ukrainerussia bilateral treaty                             NaN
# the second nuclear nonproliferation treaty                          NaN
# the moribund antiballistic missile treaty                           NaN
# the viennabased comprehensive nucleartestban tr...                  NaN
# the onepage moscow treaty                                           NaN
# the useuratom treaty                                                NaN
# the clintondesigned, abm treaty                                     NaN
# the 1970 treaty                                                     NaN
# the un treaty                                                       NaN
# the partial test ban treaty                                         NaN
# the collective security treaty                                      NaN
# the antiballistic missile defense treaty                            NaN
# the 1972 abm treaty                                                 NaN
# the obamaputin new start treaty                                     NaN
# the longstanding nuclear nonproliferation treaty                    NaN
# the npt [nuclear nonproliferation treaty                            NaN
# the north atlantaic treaty                                          NaN
# the 10page treaty                                                   NaN
# the central treaty                                                  NaN
# the 2017 united nations treaty                                      NaN
# the 1987 treaty                                                     NaN
# the july, 2017, u.n. treaty                                         NaN
# the abandoned start ii treaty                                       NaN
# the 1970 non proliferation treaty                                   NaN
# the ornate treaty                                                   NaN
# the francogerman aachen treaty                                      NaN
# the 1949 north atlantic treaty                                      NaN
# the punitive versailles treaty                                      NaN
# the new strategic reductions treaty                                 NaN
# the existingintermediaterange nuclear forces tr...                  NaN
# the western pacific. treaty                                         NaN
# the separate nuclear nonproliferation treaty                        NaN
# the command “supports #openskies treaty                             NaN
# the u.s.japan treaty                                                NaN
# the 96hour treaty                                                   NaN
# the 1963 francogerman elysée treaty                                 NaN
# the mine ban treaty                                                 NaN
# the summit, north atlantic treaty                                   NaN
# the arms trade treaty                                               NaN
# the panama canal treaty                                             NaN
# the iran nuclear treaty                                             NaN
# the oslo treaty                                                     NaN
# the organization's founding washington treaty                       NaN
#
# Submessages                                         OLD Arms Reduction  \
# treaty
# the nuclear nonproliferation treaty                           0.028939
# the nonproliferation treaty                                   0.053531
# the north atlantic treaty                                     0.004076
# the new start treaty                                          0.066055
# the intermediaterange nuclear forces treaty                   0.178771
# the treaty                                                    0.034091
# the comprehensive test ban treaty                             0.065089
# the antiballistic missile treaty                              0.086275
# the inf treaty                                                0.160976
# the comprehensive nucleartestban treaty                            NaN
# the 1968 nuclear nonproliferation treaty                      0.011976
# the 1970 nuclear nonproliferation treaty                      0.072289
# the strategic arms reduction treaty                           0.009259
# the nuclear non proliferation treaty                               NaN
# the comprehensive testban treaty                                   NaN
# the 1972 antiballistic missile treaty                         0.066667
# the international nuclear nonproliferation treaty                  NaN
# the start treaty                                                   NaN
# the intermediate nuclear forces treaty                        0.042254
# the 2015 nuclear nonproliferation treaty                      0.718750
# the nato treaty                                                    NaN
# the 2010 new start treaty                                     0.239130
# the limited test ban treaty                                   0.066667
# the abm treaty                                                0.136364
# the non proliferation treaty                                  0.113636
# the north american treaty                                          NaN
# the npt (nonproliferation treaty                                   NaN
# the global nonproliferation treaty                            0.081081
# the nuclearnonproliferation treaty                                 NaN
# the 1970 nonproliferation treaty                              0.272727
# the [nuclear nonproliferation treaty                               NaN
# the nuclear test ban treaty                                   0.156250
# the washington treaty                                              NaN
# the comprehensive nuclear testban treaty                           NaN
# the strategic offensive reductions treaty                     0.033333
# the u.n.'s nuclear nonproliferation treaty                    0.480000
# the sea treaty                                                0.040000
# the fissile material cutoff treaty                                 NaN
# the nowdefunct antiballistic missile treaty                        NaN
# the 1968 nonproliferation treaty                                   NaN
# the parliament's move.=========================...                 NaN
# the comprehensive nucleartest ban treaty                           NaN
# the international nonproliferation treaty                          NaN
# the global nuclear nonproliferation treaty                         NaN
# the 1987 inf treaty                                           0.190476
# the 189nation nuclear nonproliferation treaty                      NaN
# the 1967 outer space treaty                                   0.166667
# the u.s.russia new start treaty                                    NaN
# the outer space treaty                                             NaN
# the threshold test ban treaty                                      NaN
# the npt (nuclear nonproliferation treaty                      0.333333
# the strategic arms limitation treaty                               NaN
# the intermediaterange forces treaty                           0.176471
# the firstever treaty                                          0.312500
# the decadesold nuclear nonproliferation treaty                0.562500
# the 2011 new start treaty                                     0.062500
# the 1992 open skies treaty                                         NaN
# the 47yearold nuclear nonproliferation treaty                      NaN
# the open skies treaty                                              NaN
# the landmark nuclear nonproliferation treaty                       NaN
# the rushedthrough new start treaty                                 NaN
# the nuclear proliferation treaty                                   NaN
# the valuable nuclear nonproliferation treaty                       NaN
# the congressional test ban treaty                             0.214286
# the u.n. treaty                                               0.153846
# the 1990 treaty                                                    NaN
# the i.n.f. treaty                                             0.545455
# the international antiballistic missile treaty                     NaN
# the next north atlantic treaty                                     NaN
# the u.s.soviet antiballistic missile treaty                        NaN
# the (nuclear nonproliferation treaty                               NaN
# the first postinf treaty                                           NaN
# the 1996 comprehensive nucleartestban treaty                       NaN
# the intermediate missile treaty                                    NaN
# the vaunted new start treaty                                       NaN
# the versailles treaty                                         0.444444
# the u.n. arms trade treaty                                         NaN
# the southeast asia treaty                                     0.625000
# the ineffective new start treaty                              0.375000
# the seventhcentury treaty                                          NaN
# the 28member north atlantic treaty                                 NaN
# the state department's treaty                                      NaN
# the union's 2009 lisbon treaty                                     NaN
# the un's comprehensive testban treaty                              NaN
# the 1972antiballistic missile (abm) treaty                    0.142857
# the socalled new start treaty                                      NaN
# the fiveyear nuclear nonproliferation treaty                  0.285714
# the 2002 moscow treaty                                        0.333333
# the intermediatenuclear forces treaty                              NaN
# the 1997 ukrainerussia bilateral treaty                            NaN
# the second nuclear nonproliferation treaty                         NaN
# the moribund antiballistic missile treaty                          NaN
# the viennabased comprehensive nucleartestban tr...                 NaN
# the onepage moscow treaty                                     0.200000
# the useuratom treaty                                               NaN
# the clintondesigned, abm treaty                                    NaN
# the 1970 treaty                                                    NaN
# the un treaty                                                      NaN
# the partial test ban treaty                                   1.000000
# the collective security treaty                                     NaN
# the antiballistic missile defense treaty                           NaN
# the 1972 abm treaty                                                NaN
# the obamaputin new start treaty                                    NaN
# the longstanding nuclear nonproliferation treaty                   NaN
# the npt [nuclear nonproliferation treaty                           NaN
# the north atlantaic treaty                                         NaN
# the 10page treaty                                                  NaN
# the central treaty                                                 NaN
# the 2017 united nations treaty                                     NaN
# the 1987 treaty                                                    NaN
# the july, 2017, u.n. treaty                                        NaN
# the abandoned start ii treaty                                      NaN
# the 1970 non proliferation treaty                             1.000000
# the ornate treaty                                                  NaN
# the francogerman aachen treaty                                     NaN
# the 1949 north atlantic treaty                                     NaN
# the punitive versailles treaty                                     NaN
# the new strategic reductions treaty                                NaN
# the existingintermediaterange nuclear forces tr...            1.000000
# the western pacific. treaty                                        NaN
# the separate nuclear nonproliferation treaty                       NaN
# the command “supports #openskies treaty                            NaN
# the u.s.japan treaty                                               NaN
# the 96hour treaty                                                  NaN
# the 1963 francogerman elysée treaty                                NaN
# the mine ban treaty                                                NaN
# the summit, north atlantic treaty                                  NaN
# the arms trade treaty                                              NaN
# the panama canal treaty                                            NaN
# the iran nuclear treaty                                            NaN
# the oslo treaty                                                    NaN
# the organization's founding washington treaty                      NaN
#
# Submessages                                         OLD CTBT  OLD Covert Ops  \
# treaty
# the nuclear nonproliferation treaty                 0.001237        0.003957
# the nonproliferation treaty                              NaN        0.003417
# the north atlantic treaty                                NaN        0.002717
# the new start treaty                                0.005505             NaN
# the intermediaterange nuclear forces treaty              NaN             NaN
# the treaty                                          0.071023             NaN
# the comprehensive test ban treaty                   0.556213             NaN
# the antiballistic missile treaty                         NaN             NaN
# the inf treaty                                           NaN             NaN
# the comprehensive nucleartestban treaty             0.089820             NaN
# the 1968 nuclear nonproliferation treaty                 NaN             NaN
# the 1970 nuclear nonproliferation treaty                 NaN             NaN
# the strategic arms reduction treaty                      NaN             NaN
# the nuclear non proliferation treaty                     NaN             NaN
# the comprehensive testban treaty                    0.355769             NaN
# the 1972 antiballistic missile treaty                    NaN             NaN
# the international nuclear nonproliferation treaty        NaN             NaN
# the start treaty                                         NaN             NaN
# the intermediate nuclear forces treaty                   NaN             NaN
# the 2015 nuclear nonproliferation treaty            0.093750        0.015625
# the nato treaty                                          NaN             NaN
# the 2010 new start treaty                                NaN             NaN
# the limited test ban treaty                              NaN             NaN
# the abm treaty                                           NaN             NaN
# the non proliferation treaty                        0.022727             NaN
# the north american treaty                                NaN             NaN
# the npt (nonproliferation treaty                         NaN             NaN
# the global nonproliferation treaty                       NaN             NaN
# the nuclearnonproliferation treaty                       NaN             NaN
# the 1970 nonproliferation treaty                         NaN             NaN
# the [nuclear nonproliferation treaty                     NaN             NaN
# the nuclear test ban treaty                              NaN             NaN
# the washington treaty                                    NaN             NaN
# the comprehensive nuclear testban treaty            0.433333             NaN
# the strategic offensive reductions treaty                NaN             NaN
# the u.n.'s nuclear nonproliferation treaty               NaN             NaN
# the sea treaty                                           NaN             NaN
# the fissile material cutoff treaty                       NaN             NaN
# the nowdefunct antiballistic missile treaty              NaN             NaN
# the 1968 nonproliferation treaty                         NaN             NaN
# the parliament's move.=========================...       NaN             NaN
# the comprehensive nucleartest ban treaty                 NaN             NaN
# the international nonproliferation treaty                NaN             NaN
# the global nuclear nonproliferation treaty               NaN             NaN
# the 1987 inf treaty                                      NaN             NaN
# the 189nation nuclear nonproliferation treaty            NaN             NaN
# the 1967 outer space treaty                              NaN             NaN
# the u.s.russia new start treaty                          NaN             NaN
# the outer space treaty                                   NaN             NaN
# the threshold test ban treaty                            NaN             NaN
# the npt (nuclear nonproliferation treaty                 NaN        0.055556
# the strategic arms limitation treaty                     NaN             NaN
# the intermediaterange forces treaty                      NaN             NaN
# the firstever treaty                                     NaN             NaN
# the decadesold nuclear nonproliferation treaty           NaN             NaN
# the 2011 new start treaty                                NaN             NaN
# the 1992 open skies treaty                               NaN             NaN
# the 47yearold nuclear nonproliferation treaty            NaN             NaN
# the open skies treaty                                    NaN             NaN
# the landmark nuclear nonproliferation treaty             NaN             NaN
# the rushedthrough new start treaty                       NaN             NaN
# the nuclear proliferation treaty                         NaN             NaN
# the valuable nuclear nonproliferation treaty             NaN             NaN
# the congressional test ban treaty                   0.142857             NaN
# the u.n. treaty                                          NaN             NaN
# the 1990 treaty                                          NaN             NaN
# the i.n.f. treaty                                        NaN             NaN
# the international antiballistic missile treaty           NaN             NaN
# the next north atlantic treaty                           NaN             NaN
# the u.s.soviet antiballistic missile treaty              NaN             NaN
# the (nuclear nonproliferation treaty                     NaN             NaN
# the first postinf treaty                                 NaN             NaN
# the 1996 comprehensive nucleartestban treaty        0.888889             NaN
# the intermediate missile treaty                          NaN             NaN
# the vaunted new start treaty                             NaN             NaN
# the versailles treaty                                    NaN             NaN
# the u.n. arms trade treaty                               NaN             NaN
# the southeast asia treaty                                NaN             NaN
# the ineffective new start treaty                         NaN             NaN
# the seventhcentury treaty                                NaN             NaN
# the 28member north atlantic treaty                       NaN             NaN
# the state department's treaty                            NaN             NaN
# the union's 2009 lisbon treaty                           NaN             NaN
# the un's comprehensive testban treaty                    NaN             NaN
# the 1972antiballistic missile (abm) treaty               NaN             NaN
# the socalled new start treaty                            NaN             NaN
# the fiveyear nuclear nonproliferation treaty             NaN             NaN
# the 2002 moscow treaty                                   NaN             NaN
# the intermediatenuclear forces treaty                    NaN             NaN
# the 1997 ukrainerussia bilateral treaty                  NaN             NaN
# the second nuclear nonproliferation treaty               NaN             NaN
# the moribund antiballistic missile treaty                NaN             NaN
# the viennabased comprehensive nucleartestban tr...       NaN             NaN
# the onepage moscow treaty                                NaN             NaN
# the useuratom treaty                                     NaN             NaN
# the clintondesigned, abm treaty                          NaN             NaN
# the 1970 treaty                                          NaN             NaN
# the un treaty                                            NaN             NaN
# the partial test ban treaty                              NaN             NaN
# the collective security treaty                           NaN             NaN
# the antiballistic missile defense treaty                 NaN             NaN
# the 1972 abm treaty                                      NaN             NaN
# the obamaputin new start treaty                          NaN             NaN
# the longstanding nuclear nonproliferation treaty         NaN             NaN
# the npt [nuclear nonproliferation treaty                 NaN             NaN
# the north atlantaic treaty                               NaN             NaN
# the 10page treaty                                        NaN             NaN
# the central treaty                                       NaN             NaN
# the 2017 united nations treaty                           NaN             NaN
# the 1987 treaty                                          NaN             NaN
# the july, 2017, u.n. treaty                              NaN             NaN
# the abandoned start ii treaty                            NaN             NaN
# the 1970 non proliferation treaty                        NaN             NaN
# the ornate treaty                                        NaN             NaN
# the francogerman aachen treaty                           NaN             NaN
# the 1949 north atlantic treaty                           NaN             NaN
# the punitive versailles treaty                           NaN             NaN
# the new strategic reductions treaty                      NaN             NaN
# the existingintermediaterange nuclear forces tr...       NaN             NaN
# the western pacific. treaty                              NaN             NaN
# the separate nuclear nonproliferation treaty             NaN             NaN
# the command “supports #openskies treaty                  NaN             NaN
# the u.s.japan treaty                                     NaN             NaN
# the 96hour treaty                                        NaN             NaN
# the 1963 francogerman elysée treaty                      NaN             NaN
# the mine ban treaty                                      NaN             NaN
# the summit, north atlantic treaty                        NaN             NaN
# the arms trade treaty                                    NaN             NaN
# the panama canal treaty                                  NaN             NaN
# the iran nuclear treaty                                  NaN             NaN
# the oslo treaty                                          NaN             NaN
# the organization's founding washington treaty            NaN             NaN
#
# Submessages                                         OLD Deployment and Testing  \
# treaty
# the nuclear nonproliferation treaty                                   0.011872
# the nonproliferation treaty                                                NaN
# the north atlantic treaty                                             0.058424
# the new start treaty                                                  0.007339
# the intermediaterange nuclear forces treaty                           0.022346
# the treaty                                                            0.028409
# the comprehensive test ban treaty                                     0.026627
# the antiballistic missile treaty                                      0.031373
# the inf treaty                                                        0.004878
# the comprehensive nucleartestban treaty                               0.053892
# the 1968 nuclear nonproliferation treaty                              0.011976
# the 1970 nuclear nonproliferation treaty                                   NaN
# the strategic arms reduction treaty                                        NaN
# the nuclear non proliferation treaty                                       NaN
# the comprehensive testban treaty                                           NaN
# the 1972 antiballistic missile treaty                                 0.011111
# the international nuclear nonproliferation treaty                          NaN
# the start treaty                                                      0.012346
# the intermediate nuclear forces treaty                                     NaN
# the 2015 nuclear nonproliferation treaty                                   NaN
# the nato treaty                                                            NaN
# the 2010 new start treaty                                                  NaN
# the limited test ban treaty                                           0.200000
# the abm treaty                                                        0.113636
# the non proliferation treaty                                               NaN
# the north american treaty                                                  NaN
# the npt (nonproliferation treaty                                           NaN
# the global nonproliferation treaty                                         NaN
# the nuclearnonproliferation treaty                                         NaN
# the 1970 nonproliferation treaty                                           NaN
# the [nuclear nonproliferation treaty                                       NaN
# the nuclear test ban treaty                                           0.062500
# the washington treaty                                                      NaN
# the comprehensive nuclear testban treaty                              0.033333
# the strategic offensive reductions treaty                                  NaN
# the u.n.'s nuclear nonproliferation treaty                                 NaN
# the sea treaty                                                             NaN
# the fissile material cutoff treaty                                         NaN
# the nowdefunct antiballistic missile treaty                           0.125000
# the 1968 nonproliferation treaty                                           NaN
# the parliament's move.=========================...                         NaN
# the comprehensive nucleartest ban treaty                                   NaN
# the international nonproliferation treaty                             0.045455
# the global nuclear nonproliferation treaty                                 NaN
# the 1987 inf treaty                                                        NaN
# the 189nation nuclear nonproliferation treaty                              NaN
# the 1967 outer space treaty                                                NaN
# the u.s.russia new start treaty                                            NaN
# the outer space treaty                                                0.466667
# the threshold test ban treaty                                              NaN
# the npt (nuclear nonproliferation treaty                                   NaN
# the strategic arms limitation treaty                                       NaN
# the intermediaterange forces treaty                                        NaN
# the firstever treaty                                                       NaN
# the decadesold nuclear nonproliferation treaty                             NaN
# the 2011 new start treaty                                                  NaN
# the 1992 open skies treaty                                                 NaN
# the 47yearold nuclear nonproliferation treaty                         0.133333
# the open skies treaty                                                 0.071429
# the landmark nuclear nonproliferation treaty                               NaN
# the rushedthrough new start treaty                                         NaN
# the nuclear proliferation treaty                                           NaN
# the valuable nuclear nonproliferation treaty                               NaN
# the congressional test ban treaty                                          NaN
# the u.n. treaty                                                       0.076923
# the 1990 treaty                                                            NaN
# the i.n.f. treaty                                                          NaN
# the international antiballistic missile treaty                             NaN
# the next north atlantic treaty                                             NaN
# the u.s.soviet antiballistic missile treaty                                NaN
# the (nuclear nonproliferation treaty                                       NaN
# the first postinf treaty                                                   NaN
# the 1996 comprehensive nucleartestban treaty                               NaN
# the intermediate missile treaty                                            NaN
# the vaunted new start treaty                                               NaN
# the versailles treaty                                                      NaN
# the u.n. arms trade treaty                                                 NaN
# the southeast asia treaty                                                  NaN
# the ineffective new start treaty                                           NaN
# the seventhcentury treaty                                                  NaN
# ...
# the international nonproliferation treaty                      NaN
# the global nuclear nonproliferation treaty                     NaN
# the 1987 inf treaty                                            NaN
# the 189nation nuclear nonproliferation treaty                  NaN
# the 1967 outer space treaty                                    NaN
# the u.s.russia new start treaty                                NaN
# the outer space treaty                                         NaN
# the threshold test ban treaty                                  NaN
# the npt (nuclear nonproliferation treaty                       NaN
# the strategic arms limitation treaty                           NaN
# the intermediaterange forces treaty                            NaN
# the firstever treaty                                           NaN
# the decadesold nuclear nonproliferation treaty                 NaN
# the 2011 new start treaty                                      NaN
# the 1992 open skies treaty                                     NaN
# the 47yearold nuclear nonproliferation treaty                  NaN
# the open skies treaty                                          NaN
# the landmark nuclear nonproliferation treaty                   NaN
# the rushedthrough new start treaty                             NaN
# the nuclear proliferation treaty                               NaN
# the valuable nuclear nonproliferation treaty                   NaN
# the congressional test ban treaty                              NaN
# the u.n. treaty                                                NaN
# the 1990 treaty                                                NaN
# the i.n.f. treaty                                              NaN
# the international antiballistic missile treaty                 NaN
# the next north atlantic treaty                                 NaN
# the u.s.soviet antiballistic missile treaty                    NaN
# the (nuclear nonproliferation treaty                           NaN
# the first postinf treaty                                       NaN
# the 1996 comprehensive nucleartestban treaty                   NaN
# the intermediate missile treaty                                NaN
# the vaunted new start treaty                                   NaN
# the versailles treaty                                          NaN
# the u.n. arms trade treaty                                     NaN
# the southeast asia treaty                                      NaN
# the ineffective new start treaty                               NaN
# the seventhcentury treaty                                      NaN
# the 28member north atlantic treaty                             NaN
# the state department's treaty                                  NaN
# the union's 2009 lisbon treaty                                 NaN
# the un's comprehensive testban treaty                          NaN
# the 1972antiballistic missile (abm) treaty                     NaN
# the socalled new start treaty                                  NaN
# the fiveyear nuclear nonproliferation treaty                   NaN
# the 2002 moscow treaty                                         NaN
# the intermediatenuclear forces treaty                          NaN
# the 1997 ukrainerussia bilateral treaty                        NaN
# the second nuclear nonproliferation treaty                     NaN
# the moribund antiballistic missile treaty                      NaN
# the viennabased comprehensive nucleartestban tr...             NaN
# the onepage moscow treaty                                      NaN
# the useuratom treaty                                           NaN
# the clintondesigned, abm treaty                                NaN
# the 1970 treaty                                                NaN
# the un treaty                                                  NaN
# the partial test ban treaty                                    NaN
# the collective security treaty                                 NaN
# the antiballistic missile defense treaty                       NaN
# the 1972 abm treaty                                            NaN
# the obamaputin new start treaty                                NaN
# the longstanding nuclear nonproliferation treaty               NaN
# the npt [nuclear nonproliferation treaty                       NaN
# the north atlantaic treaty                                     NaN
# the 10page treaty                                              NaN
# the central treaty                                             NaN
# the 2017 united nations treaty                                 NaN
# the 1987 treaty                                                NaN
# the july, 2017, u.n. treaty                                    NaN
# the abandoned start ii treaty                                  NaN
# the 1970 non proliferation treaty                              NaN
# the ornate treaty                                              NaN
# the francogerman aachen treaty                                 NaN
# the 1949 north atlantic treaty                                 NaN
# the punitive versailles treaty                                 NaN
# the new strategic reductions treaty                            NaN
# the existingintermediaterange nuclear forces tr...             NaN
# the western pacific. treaty                                    NaN
# the separate nuclear nonproliferation treaty                   NaN
# the command “supports #openskies treaty                        NaN
# the u.s.japan treaty                                           NaN
# the 96hour treaty                                              NaN
# the 1963 francogerman elysée treaty                            NaN
# the mine ban treaty                                            NaN
# the summit, north atlantic treaty                              NaN
# the arms trade treaty                                          NaN
# the panama canal treaty                                        NaN
# the iran nuclear treaty                                        NaN
# the oslo treaty                                                NaN
# the organization's founding washington treaty                  NaN
#
# Submessages                                         OLD Sequestration
# treaty
# the nuclear nonproliferation treaty                               NaN
# the nonproliferation treaty                                       NaN
# the north atlantic treaty                                         NaN
# the new start treaty                                         0.007339
# the intermediaterange nuclear forces treaty                       NaN
# the treaty                                                        NaN
# the comprehensive test ban treaty                                 NaN
# the antiballistic missile treaty                                  NaN
# the inf treaty                                                    NaN
# the comprehensive nucleartestban treaty                           NaN
# the 1968 nuclear nonproliferation treaty                          NaN
# the 1970 nuclear nonproliferation treaty                          NaN
# the strategic arms reduction treaty                          0.027778
# the nuclear non proliferation treaty                              NaN
# the comprehensive testban treaty                                  NaN
# the 1972 antiballistic missile treaty                             NaN
# the international nuclear nonproliferation treaty                 NaN
# the start treaty                                                  NaN
# the intermediate nuclear forces treaty                            NaN
# the 2015 nuclear nonproliferation treaty                          NaN
# the nato treaty                                                   NaN
# the 2010 new start treaty                                         NaN
# the limited test ban treaty                                       NaN
# the abm treaty                                                    NaN
# the non proliferation treaty                                      NaN
# the north american treaty                                         NaN
# the npt (nonproliferation treaty                                  NaN
# the global nonproliferation treaty                                NaN
# the nuclearnonproliferation treaty                                NaN
# the 1970 nonproliferation treaty                                  NaN
# the [nuclear nonproliferation treaty                              NaN
# the nuclear test ban treaty                                       NaN
# the washington treaty                                             NaN
# the comprehensive nuclear testban treaty                          NaN
# the strategic offensive reductions treaty                         NaN
# the u.n.'s nuclear nonproliferation treaty                        NaN
# the sea treaty                                                    NaN
# the fissile material cutoff treaty                                NaN
# the nowdefunct antiballistic missile treaty                       NaN
# the 1968 nonproliferation treaty                                  NaN
# the parliament's move.=========================...                NaN
# the comprehensive nucleartest ban treaty                          NaN
# the international nonproliferation treaty                         NaN
# the global nuclear nonproliferation treaty                        NaN
# the 1987 inf treaty                                               NaN
# the 189nation nuclear nonproliferation treaty                     NaN
# the 1967 outer space treaty                                       NaN
# the u.s.russia new start treaty                                   NaN
# the outer space treaty                                            NaN
# the threshold test ban treaty                                     NaN
# the npt (nuclear nonproliferation treaty                          NaN
# the strategic arms limitation treaty                              NaN
# the intermediaterange forces treaty                               NaN
# the firstever treaty                                              NaN
# the decadesold nuclear nonproliferation treaty                    NaN
# the 2011 new start treaty                                         NaN
# the 1992 open skies treaty                                        NaN
# the 47yearold nuclear nonproliferation treaty                     NaN
# the open skies treaty                                             NaN
# the landmark nuclear nonproliferation treaty                      NaN
# the rushedthrough new start treaty                                NaN
# the nuclear proliferation treaty                                  NaN
# the valuable nuclear nonproliferation treaty                      NaN
# the congressional test ban treaty                                 NaN
# the u.n. treaty                                                   NaN
# the 1990 treaty                                                   NaN
# the i.n.f. treaty                                                 NaN
# the international antiballistic missile treaty                    NaN
# the next north atlantic treaty                                    NaN
# the u.s.soviet antiballistic missile treaty                       NaN
# the (nuclear nonproliferation treaty                              NaN
# the first postinf treaty                                          NaN
# the 1996 comprehensive nucleartestban treaty                      NaN
# the intermediate missile treaty                                   NaN
# the vaunted new start treaty                                      NaN
# the versailles treaty                                             NaN
# the u.n. arms trade treaty                                        NaN
# the southeast asia treaty                                         NaN
# the ineffective new start treaty                                  NaN
# the seventhcentury treaty                                         NaN
# the 28member north atlantic treaty                                NaN
# the state department's treaty                                     NaN
# the union's 2009 lisbon treaty                                    NaN
# the un's comprehensive testban treaty                             NaN
# the 1972antiballistic missile (abm) treaty                        NaN
# the socalled new start treaty                                     NaN
# the fiveyear nuclear nonproliferation treaty                      NaN
# the 2002 moscow treaty                                            NaN
# the intermediatenuclear forces treaty                             NaN
# the 1997 ukrainerussia bilateral treaty                           NaN
# the second nuclear nonproliferation treaty                        NaN
# the moribund antiballistic missile treaty                         NaN
# the viennabased comprehensive nucleartestban tr...                NaN
# the onepage moscow treaty                                         NaN
# the useuratom treaty                                              NaN
# the clintondesigned, abm treaty                                   NaN
# the 1970 treaty                                                   NaN
# the un treaty                                                     NaN
# the partial test ban treaty                                       NaN
# the collective security treaty                                    NaN
# the antiballistic missile defense treaty                          NaN
# the 1972 abm treaty                                               NaN
# the obamaputin new start treaty                                   NaN
# the longstanding nuclear nonproliferation treaty                  NaN
# the npt [nuclear nonproliferation treaty                          NaN
# the north atlantaic treaty                                        NaN
# the 10page treaty                                                 NaN
# the central treaty                                                NaN
# the 2017 united nations treaty                                    NaN
# the 1987 treaty                                                   NaN
# the july, 2017, u.n. treaty                                       NaN
# the abandoned start ii treaty                                     NaN
# the 1970 non proliferation treaty                                 NaN
# the ornate treaty                                                 NaN
# the francogerman aachen treaty                                    NaN
# the 1949 north atlantic treaty                                    NaN
# the punitive versailles treaty                                    NaN
# the new strategic reductions treaty                               NaN
# the existingintermediaterange nuclear forces tr...                NaN
# the western pacific. treaty                                       NaN
# the separate nuclear nonproliferation treaty                      NaN
# the command “supports #openskies treaty                           NaN
# the u.s.japan treaty                                              NaN
# the 96hour treaty                                                 NaN
# the 1963 francogerman elysée treaty                               NaN
# the mine ban treaty                                               NaN
# the summit, north atlantic treaty                                 NaN
# the arms trade treaty                                             NaN
# the panama canal treaty                                           NaN
# the iran nuclear treaty                                           NaN
# the oslo treaty                                                   NaN
# the organization's founding washington treaty                     NaN
#
# [132 rows x 34 columns]

# %%
# table with treaty & most common message (highest prop)
most_common_submessage = []
for i in np.arange(len(treaty_submessage_table)):
    most_common_submessage.append(pd.DataFrame(treaty_submessage_table.iloc[i, :]).idxmax()[0])

# %%
treaty_submessage_table['most common submessage'] = most_common_submessage

# %%
treaty_submessage_table = treaty_submessage_table.reset_index()[['treaty', 'most common submessage']]
treaty_submessage_table = treaty_submessage_table.rename_axis(None, axis=1)

# %%
treaty_submessage_table
# Out:
#                                                 treaty  \
# 0                  the nuclear nonproliferation treaty
# 1                          the nonproliferation treaty
# 2                            the north atlantic treaty
# 3                                 the new start treaty
# 4          the intermediaterange nuclear forces treaty
# 5                                           the treaty
# 6                    the comprehensive test ban treaty
# 7                     the antiballistic missile treaty
# 8                                       the inf treaty
# 9              the comprehensive nucleartestban treaty
# 10            the 1968 nuclear nonproliferation treaty
# 11            the 1970 nuclear nonproliferation treaty
# 12                 the strategic arms reduction treaty
# 13                the nuclear non proliferation treaty
# 14                    the comprehensive testban treaty
# 15               the 1972 antiballistic missile treaty
# 16   the international nuclear nonproliferation treaty
# 17                                    the start treaty
# 18              the intermediate nuclear forces treaty
# 19            the 2015 nuclear nonproliferation treaty
# 20                                     the nato treaty
# 21                           the 2010 new start treaty
# 22                         the limited test ban treaty
# 23                                      the abm treaty
# 24                        the non proliferation treaty
# 25                           the north american treaty
# 26                    the npt (nonproliferation treaty
# 27                  the global nonproliferation treaty
# 28                  the nuclearnonproliferation treaty
# 29                    the 1970 nonproliferation treaty
# 30                the [nuclear nonproliferation treaty
# 31                         the nuclear test ban treaty
# 32                               the washington treaty
# 33            the comprehensive nuclear testban treaty
# 34           the strategic offensive reductions treaty
# 35          the u.n.'s nuclear nonproliferation treaty
# 36                                      the sea treaty
# 37                  the fissile material cutoff treaty
# 38         the nowdefunct antiballistic missile treaty
# 39                    the 1968 nonproliferation treaty
# 40   the parliament's move.========================...
# 41            the comprehensive nucleartest ban treaty
# 42           the international nonproliferation treaty
# 43          the global nuclear nonproliferation treaty
# 44                                 the 1987 inf treaty
# 45       the 189nation nuclear nonproliferation treaty
# 46                         the 1967 outer space treaty
# 47                     the u.s.russia new start treaty
# 48                              the outer space treaty
# 49                       the threshold test ban treaty
# 50            the npt (nuclear nonproliferation treaty
# 51                the strategic arms limitation treaty
# 52                 the intermediaterange forces treaty
# 53                                the firstever treaty
# 54      the decadesold nuclear nonproliferation treaty
# 55                           the 2011 new start treaty
# 56                          the 1992 open skies treaty
# 57       the 47yearold nuclear nonproliferation treaty
# 58                               the open skies treaty
# 59        the landmark nuclear nonproliferation treaty
# 60                  the rushedthrough new start treaty
# 61                    the nuclear proliferation treaty
# 62        the valuable nuclear nonproliferation treaty
# 63                   the congressional test ban treaty
# 64                                     the u.n. treaty
# 65                                     the 1990 treaty
# 66                                   the i.n.f. treaty
# 67      the international antiballistic missile treaty
# 68                      the next north atlantic treaty
# 69         the u.s.soviet antiballistic missile treaty
# 70                the (nuclear nonproliferation treaty
# 71                            the first postinf treaty
# 72        the 1996 comprehensive nucleartestban treaty
# 73                     the intermediate missile treaty
# 74                        the vaunted new start treaty
# 75                               the versailles treaty
# 76                          the u.n. arms trade treaty
# 77                           the southeast asia treaty
# 78                    the ineffective new start treaty
# 79                           the seventhcentury treaty
# 80                  the 28member north atlantic treaty
# 81                       the state department's treaty
# 82                      the union's 2009 lisbon treaty
# 83               the un's comprehensive testban treaty
# 84          the 1972antiballistic missile (abm) treaty
# 85                       the socalled new start treaty
# 86        the fiveyear nuclear nonproliferation treaty
# 87                              the 2002 moscow treaty
# 88               the intermediatenuclear forces treaty
# 89             the 1997 ukrainerussia bilateral treaty
# 90          the second nuclear nonproliferation treaty
# 91           the moribund antiballistic missile treaty
# 92   the viennabased comprehensive nucleartestban t...
# 93                           the onepage moscow treaty
# 94                                the useuratom treaty
# 95                     the clintondesigned, abm treaty
# 96                                     the 1970 treaty
# 97                                       the un treaty
# 98                         the partial test ban treaty
# 99                      the collective security treaty
# 100           the antiballistic missile defense treaty
# 101                                the 1972 abm treaty
# 102                    the obamaputin new start treaty
# 103   the longstanding nuclear nonproliferation treaty
# 104           the npt [nuclear nonproliferation treaty
# 105                         the north atlantaic treaty
# 106                                  the 10page treaty
# 107                                 the central treaty
# 108                     the 2017 united nations treaty
# 109                                    the 1987 treaty
# 110                        the july, 2017, u.n. treaty
# 111                      the abandoned start ii treaty
# 112                  the 1970 non proliferation treaty
# 113                                  the ornate treaty
# 114                     the francogerman aachen treaty
# 115                     the 1949 north atlantic treaty
# 116                     the punitive versailles treaty
# 117                the new strategic reductions treaty
# 118  the existingintermediaterange nuclear forces t...
# 119                        the western pacific. treaty
# 120       the separate nuclear nonproliferation treaty
# 121            the command “supports #openskies treaty
# 122                               the u.s.japan treaty
# 123                                  the 96hour treaty
# 124                the 1963 francogerman elysée treaty
# 125                                the mine ban treaty
# 126                  the summit, north atlantic treaty
# 127                              the arms trade treaty
# 128                            the panama canal treaty
# 129                            the iran nuclear treaty
# 130                                    the oslo treaty
# 131      the organization's founding washington treaty
#
#                    most common submessage
# 0                        OLD Negotiations
# 1                        OLD Negotiations
# 2    OLD European/Russian Missile Defense
# 3                        OLD START Treaty
# 4                        OLD START Treaty
# 5        OLD State Level Nuclear Programs
# 6                                OLD CTBT
# 7    OLD European/Russian Missile Defense
# 8                          OLD INF Treaty
# 9        OLD State Level Nuclear Programs
# 10                                OLD NPT
# 11       OLD State Level Nuclear Programs
# 12                       OLD Russia Reset
# 13                       OLD Negotiations
# 14                               OLD CTBT
# 15   OLD European/Russian Missile Defense
# 16                       OLD Negotiations
# 17                       OLD Russia Reset
# 18   OLD European/Russian Missile Defense
# 19                     OLD Arms Reduction
# 20                       OLD Russia Reset
# 21                       OLD START Treaty
# 22                       OLD Negotiations
# 23   OLD European/Russian Missile Defense
# 24                       OLD Negotiations
# 25                       OLD Russia Reset
# 26                       OLD Negotiations
# 27       OLD State Level Nuclear Programs
# 28                       OLD Negotiations
# 29       OLD State Level Nuclear Programs
# 30          OLD Iranian Domestic Politics
# 31                       OLD START Treaty
# 32   OLD European/Russian Missile Defense
# 33       OLD State Level Nuclear Programs
# 34                       OLD START Treaty
# 35                     OLD Arms Reduction
# 36                       OLD Russia Reset
# 37            OLD Loose Nuclear Materials
# 38                  OLD Domestic Programs
# 39       OLD State Level Nuclear Programs
# 40                       OLD Russia Reset
# 41       OLD State Level Nuclear Programs
# 42          OLD Iranian Domestic Politics
# 43       OLD State Level Nuclear Programs
# 44       OLD State Level Nuclear Programs
# 45                       OLD Negotiations
# 46       OLD State Level Nuclear Programs
# 47              OLD Nukes Budget Campaign
# 48             OLD Deployment and Testing
# 49                       OLD Negotiations
# 50                     OLD Arms Reduction
# 51                       OLD START Treaty
# 52                         OLD US Arsenal
# 53       OLD State Level Nuclear Programs
# 54                     OLD Arms Reduction
# 55                       OLD START Treaty
# 56                       OLD Negotiations
# 57       OLD State Level Nuclear Programs
# 58                       OLD Russia Reset
# 59                   OLD Terrorist Threat
# 60   OLD European/Russian Missile Defense
# 61                       OLD Negotiations
# 62              OLD Nukes Budget Campaign
# 63    OLD Fissile Material Cut Off Treaty
# 64       OLD State Level Nuclear Programs
# 65   OLD European/Russian Missile Defense
# 66                     OLD Arms Reduction
# 67   OLD European/Russian Missile Defense
# 68   OLD European/Russian Missile Defense
# 69                  OLD Domestic Programs
# 70                       OLD Negotiations
# 71                  OLD Domestic Programs
# 72                               OLD CTBT
# 73                       OLD Russia Reset
# 74                       OLD START Treaty
# 75                     OLD Arms Reduction
# 76          OLD Iranian Domestic Politics
# 77                     OLD Arms Reduction
# 78                       OLD START Treaty
# 79                       OLD Negotiations
# 80                          OLD  Politics
# 81       OLD State Level Nuclear Programs
# 82       OLD State Level Nuclear Programs
# 83       OLD State Level Nuclear Programs
# 84                         OLD US Arsenal
# 85       OLD State Level Nuclear Programs
# 86                       OLD START Treaty
# 87                     OLD Arms Reduction
# 88   OLD European/Russian Missile Defense
# 89                  OLD Domestic Programs
# 90                         OLD US Arsenal
# 91                  OLD Domestic Programs
# 92       OLD State Level Nuclear Programs
# 93                       OLD START Treaty
# 94       OLD State Level Nuclear Programs
# 95   OLD European/Russian Missile Defense
# 96       OLD State Level Nuclear Programs
# 97       OLD State Level Nuclear Programs
# 98                     OLD Arms Reduction
# 99                       OLD Russia Reset
# 100                 OLD Domestic Programs
# 101                      OLD Negotiations
# 102                         OLD  Politics
# 103                      OLD Negotiations
# 104                      OLD Negotiations
# 105                        OLD INF Treaty
# 106            OLD Deployment and Testing
# 107                         OLD  Politics
# 108                        OLD US Arsenal
# 109                 OLD Domestic Programs
# 110      OLD State Level Nuclear Programs
# 111            OLD Deployment and Testing
# 112                    OLD Arms Reduction
# 113      OLD State Level Nuclear Programs
# 114                        OLD US Arsenal
# 115                      OLD Russia Reset
# 116      OLD State Level Nuclear Programs
# 117  OLD European/Russian Missile Defense
# 118                    OLD Arms Reduction
# 119            OLD Deployment and Testing
# 120      OLD State Level Nuclear Programs
# 121                      OLD START Treaty
# 122                      OLD Russia Reset
# 123            OLD Deployment and Testing
# 124      OLD State Level Nuclear Programs
# 125                         OLD  Politics
# 126  OLD European/Russian Missile Defense
# 127            OLD Deployment and Testing
# 128         OLD Iranian Domestic Politics
# 129      OLD State Level Nuclear Programs
# 130      OLD State Level Nuclear Programs
# 131                      OLD Negotiations

# %% [markdown]
# # accuracy of topic (submessages) classification based on treaty

# %%
# extract articles with mentions of treaties
treaty_articles = merged_df.dropna(subset=['Treaties2'])

# %%
treaty_articles = treaty_articles.loc[treaty_articles['Treaties2'].isin(treaty_submessage_table['treaty'])]

# %%
predicted_submessage = []
for i in np.arange(len(treaty_articles)):
    # find treaty in treaty_message_table, append most common message
    treaty = treaty_articles.reset_index()['Treaties2'][i]
    treaty_submessage = treaty_submessage_table.loc[treaty_submessage_table['treaty'] == treaty]['most common submessage'].item()
    predicted_submessage.append(treaty_submessage)

# %%
true_predicted_submessage_table = treaty_articles[['Submessages']].reset_index(drop=True)
true_predicted_submessage_table['predicted_submessage'] = predicted_submessage
true_predicted_submessage_table = true_predicted_submessage_table.rename(columns= {'Submessages': 'true_submessage'})

# %%
true_predicted_submessage_table
# Out:
#                         true_submessage                  predicted_submessage
# 0                    OLD Arms Reduction                    OLD Arms Reduction
# 1                    OLD Arms Reduction                    OLD Arms Reduction
# 2                    OLD Arms Reduction                    OLD Arms Reduction
# 3      OLD State Level Nuclear Programs                      OLD Negotiations
# 4      OLD State Level Nuclear Programs                      OLD Negotiations
# ...                                 ...                                   ...
# 10584                  OLD START Treaty                        OLD INF Treaty
# 10585  OLD State Level Nuclear Programs                        OLD INF Treaty
# 10586        OLD Deployment and Testing  OLD European/Russian Missile Defense
# 10587                    OLD INF Treaty  OLD European/Russian Missile Defense
# 10588        OLD Deployment and Testing  OLD European/Russian Missile Defense
#
# [10589 rows x 2 columns]

# %%
correct = sum(true_predicted_submessage_table['true_submessage'] == true_predicted_submessage_table['predicted_submessage'])
total = len(true_predicted_submessage_table)
accuracy = correct/total
accuracy
# Out:
# 0.4033430918878081

# %% [markdown]
# # only post april 2020 data

# %%
post_april_2020 = merged_df.loc[merged_df['Published Date'] >= '2020-04-00 00:00:00+00']

# %%
post_april_2020['Submessages'].unique()
# Out:
# array([nan, 'Loose Fissile Materials', 'US/NATO Missile Defense',
#        'Conflict with North Korea', 'Health Issues',
#        'OLD State Level Nuclear Programs', 'JCPOA', 'Iran Negotiations',
#        'Spending and Modernization', 'US Nuclear Arsenal', 'NPT',
#        'Worldwide Nukes Policy'], dtype=object)

# %% [markdown]
# find proportion of articles with the given treaty in the different Submessages

# %%
def submessage_treaty_props2(treaty, topic_column):
    table =  post_april_2020.loc[post_april_2020['Treaties2'] == treaty].groupby(by = topic_column).count()
    table = table.reset_index().iloc[:,0:2].rename(columns = {'Unnamed: 0' : 'count'})
    total = sum(table['count'])
    props = []
    for i in np.arange(len(table)):
        props.append(table['count'][i] / total)
    table['props'] = props
    table['treaty'] = treaty
    return table[['treaty', topic_column, 'props']]

# %%
treaty_submessage_table2 = submessage_treaty_props2(treaties_list[0], 'Submessages')
treaty_submessage_table2= pd.pivot_table(treaty_submessage_table2, values = 'props', index = ['treaty'], columns = ['Submessages'])

for i in treaties_list[1:]:
    table = submessage_treaty_props2(i, 'Submessages')
    table = pd.pivot_table(table, values = 'props', index = ['treaty'], columns = ['Submessages'])
    treaty_submessage_table2 = pd.concat([treaty_submessage_table2, table])

# %%
pd.set_option('display.max_rows', len(treaty_submessage_table2))
treaty_submessage_table2
# Out:
# Submessages                          NPT  US Nuclear Arsenal
# treaty
# the nuclear nonproliferation treaty  0.5                 0.5

# %%
# table with treaty & most common message (highest prop)
most_common_submessage2 = []
for i in np.arange(len(treaty_submessage_table2)):
    most_common_submessage2.append(pd.DataFrame(treaty_submessage_table2.iloc[i, :]).idxmax()[0])

# %%
treaty_submessage_table2['most common submessage'] = most_common_submessage2

# %%
treaty_submessage_table2 = treaty_submessage_table2.reset_index()[['treaty', 'most common submessage']]
treaty_submessage_table2 = treaty_submessage_table2.rename_axis(None, axis=1)

# %%
treaty_submessage_table2
# Out:
#                                 treaty most common submessage
# 0  the nuclear nonproliferation treaty                    NPT

# %% [markdown]
# accuracy of topic (submessages) classification based on treaty

# %%
# extract articles with mentions of treaties
treaty_articles2 = post_april_2020.dropna(subset=['Treaties2'])

# %%
treaty_articles2 = treaty_articles2.loc[treaty_articles2['Treaties2'].isin(treaty_submessage_table2['treaty'])]

# %%
predicted_submessage2 = []
for i in np.arange(len(treaty_articles2)):
    # find treaty in treaty_message_table, append most common message
    treaty = treaty_articles2.reset_index()['Treaties2'][i]
    treaty_submessage = treaty_submessage_table2.loc[treaty_submessage_table2['treaty'] == treaty]['most common submessage'].item()
    predicted_submessage2.append(treaty_submessage)

# %%
true_predicted_submessage_table2 = treaty_articles2[['Submessages']].reset_index(drop=True)
true_predicted_submessage_table2['predicted_submessage'] = predicted_submessage2
true_predicted_submessage_table2 = true_predicted_submessage_table2.rename(columns= {'Submessages': 'true_submessage'})

# %%
true_predicted_submessage_table2
# Out:
#        true_submessage predicted_submessage
# 0   US Nuclear Arsenal                  NPT
# ..                 ...                  ...
#
# [2 rows x 2 columns]

# %%
correct = sum(true_predicted_submessage_table2['true_submessage'] == true_predicted_submessage_table2['predicted_submessage'])
total = len(true_predicted_submessage_table2)
accuracy = correct/total
accuracy
# Out:
# 0.5

# %% [markdown]
# main findings
# - treaties better for classifying message topics (than submessage topic categories)
#     - accuracies:
#         - presence of certain treaty (treaty, Messages) ~ 0.58 (entire dataset)
#         - presence of certain treaty (treaty, Submessages) ~ 0.40 (entire dataset)
#         - presence of certain treaty (treaty, Submessages) ~ 0.5 (articles after April 2020)
